# %% [markdown]
# # Effects on Air Quality During COVID-19
#
#
# ### INTRODUCTION
#
# The COVID-19 (also referred to as coronavirus) has impacted every corner of the globe, with every country reporting cases according to Johns Hopkins University's Coronavirus [tracker](https://coronavirus.jhu.edu/map.html). Governments - at the national, state and local level - have ordered the closure of non-essential business, organizations and schools. Social distancing rules and stay at home orders have been implemented in an effort to slow the spread of the disease. These actions have resulted in the shuttering of factories and have led to significant decreases in energy consumption. This in turn has reduced air pollution and improved air quality in many cities and countries known for poor air conditions. News outlets ([CNN](https://www.cnn.com/travel/article/himalayas-visible-lockdown-india-scli-intl/index.html), [Guardian](https://www.theguardian.com/environment/2020/apr/11/positively-alpine-disbelief-air-pollution-falls-lockdown-coronavirus)) have reported that this decrease in air pollution has been most notable in developing countries with lax to no environmental laws and regulations.
#
# By looking at a variety of pollutant measurements, we can determine the impact of COVID-19 on air quality. Additionally, as localities begin to restart their economies and return to normalcy, we likely will see a rise in pollution. Essentially, we want to know if air quality can be a proxy for economic activity. Further, we want to mine social media data to see if users are mentioning air quality impacts. Analyzing pictures from social media may also serve as a signal as to the quality of air in certain geographies.
#
# **Project Goals**
#
# Our objective of this project is to obtain air quality and social media data  from various sources and evaluate the impact of COVID-19 on air quality in the following global locations:
#   - Los Angeles, CA, USA
#   - Honolulu, HI, USA
#   - New Delhi, India
#   - Seoul, South Korea
#   - Beijing, China
#
# From here we will review historical and current images and air quality information of each location and determine what effect, if any, the stay at home orders have produced. We will also compare COVID-19 positive cases in each location to their respective air quality information and determine if there is a direct correlation to the air quality and number of COVID-19 cases.
#
#
#
# **Possible Data Sources**
#
# - [Breezometer](https://docs.breezometer.com/)
# - [Open AQ](https://docs.openaq.org/)
# - [Climacell](https://www.climacell.co/)
# - [NASA](https://api.nasa.gov/)
# - [EPA](https://aqs.epa.gov/aqsweb/documents/data_api.html)
# - [Twitter](https://developer.twitter.com/en/docs)
#
# **How The Data Is Generated**
#
# Our data is coming from a variety of sources. The pollution and weather data is generated from numerous sensors in specific geographic locations. These sensors measure gases and particulate matter in the atmosphere and are generally maintained by government, scientific and academic organizations. Social media data is user generated.
#
# **Data Access and Rights**
#
# The government agencies and institutions provide access to the public free of charge. Additionally, there are corporations that limit who has access to their data and charge for this access. Nonetheless, they offer free limited trials of their services which will aid in this project.
#
# **Interested Parties**
#
# This data would be of interest to policy makers, environmentalists, health care officials, individuals with health issues exasperated by poor air quality and others. This data could help shape policy both from an environmental as well as an economic perspective.

# %% [markdown]
# ### COVID-19 statistics - Number of Cases and Number of Deaths

# %% [markdown]
# Outlined below is real time statistics of the geographical areas selected for evaluation. In some instances data was pulled for the respective county (in the US) and country (China).

# %%
from bs4 import BeautifulSoup
import urllib, requests 
from datetime import datetime
import pandas as pd
import numpy as np
import re
import requests
import os
from pprint import pprint
from collections import defaultdict
from PIL import Image
import numpy as np

# %% [markdown]
# **Los Angeles County, CA, USA**

# %%
Covid_cases = defaultdict(list)

# %%
#Provide data on total Coronavirus cases and coronavirus deaths in Los Angeles County, CA, USA
html = urllib.request.urlopen('https://covid19.lacounty.gov/').read()
soup = BeautifulSoup(html, 'html.parser')
body = soup.find('body')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 10]>
# <html class="ie9 no-js"  xmlns="http://www.w3.org/1999/xhtml" prefix="og: http://ogp.me/ns# fb: https://www.facebook.com/2008/fbml" lang="en-US">
# <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!-->
# <html class="no-js" lang="en-US" prefix="og: http://ogp.me/ns# fb: https://www.facebook.com/2008/fbml" xmlns="http://www.w3.org/1999/xhtml"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <!-- BEGIN Metadata added by the Add-Meta-Tags WordPress plugin -->
# <meta/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="Efforts are underway to respond to the coronavirus (COVID-19) outbreak." name="description">
# <meta content="coronavirus, cdc, public health, covid 19, la county" name="keywords">
# <meta content="website" property="og:type">
# <meta content="COUNTY OF LOS ANGELES" property="og:site_name"/>
# <meta content="Confronting COVID-19: LA County Responds" property="og:title"/>
# <meta content="https://covid19.lacounty.gov/" property="og:url"/>
# <meta content="Efforts are underway to respond to the coronavirus (COVID-19) outbreak." property="og:description"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="https://covid19.lacounty.gov/wp-content/uploads/covid19-home-page-banner.png" property="og:image"/>
# <meta content="https://covid19.lacounty.gov/wp-content/uploads/covid19-home-page-banner.png" property="og:image:secure_url"/>
# <meta content="1920" property="og:image:width"/>
# <meta content="1080" property="og:image:height"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="Confronting COVID-19: LA County Responds" name="twitter:title"/>
# <meta content="Efforts are underway to respond to the coronavirus (COVID-19) outbreak." name="twitter:description"/>
# <meta content="https://covid19.lacounty.gov/wp-content/uploads/covid19-home-page-banner.png" name="twitter:image"/>
# <meta content="1920" name="twitter:image:width"/>
# <meta content="1080" name="twitter:image:height"/>
# <!-- END Metadata added by the Add-Meta-Tags WordPress plugin -->
# <title>Confronting COVID-19: LA County Responds</title>
# <style data-type="vc_custom-css" type="text/css">.elegant-tabs-container {
#   margin-top: -52px;
#   z-index: 10;
# }
# #grve-main-content .et-tabs.et-horizontal .et-content-wrap section {
#   padding: 26px;
# }
# #grve-main-content .et-tabs .rev_slider_wrapper {
#   padding: 0 !important;
# }
# /* #grve-main-content .vc_tta-tabs .vc_tta-tabs-container {
#   margin-bottom: -10px;
# } */
# .custom-homepage-wrapper {
#   padding-top: 10px !important;
# }
# @media only screen and (max-width: 244px) {
#   .custom-homepage-wrapper {
#     padding-top: 160px !important;
#   }
# }</style><style data-type="vc_shortcodes-custom-css" type="text/css">.vc_custom_1584906360927{margin-top: 25px !important;border-top-width: 25px !important;padding-top: 25px !important;}.vc_custom_1590179693906{margin-right: 0px !important;margin-left: 0px !important;border-right-width: 0px !important;border-left-width: 0px !important;padding-right: 0px !important;padding-left: 0px !important;}.vc_custom_1590179693906{margin-right: 0px !important;margin-left: 0px !important;border-right-width: 0px !important;border-left-width: 0px !important;padding-right: 0px !important;padding-left: 0px !important;}.vc_custom_1588613677114{padding-top: -10px !important;}.vc_custom_1588613680365{padding-top: -10px !important;}.vc_custom_1591034250753{margin-top: 0px !important;margin-right: 0px !important;margin-left: 0px !important;border-top-width: 0px !important;border-right-width: 0px !important;border-left-width: 0px !important;padding-top: 0px !important;padding-right: 0px !important;padding-left: 0px !important;}.vc_custom_1591034276865{margin-right: 0px !important;margin-left: 0px !important;border-right-width: 0px !important;border-left-width: 0px !important;padding-top: 10px !important;padding-right: 0px !important;padding-bottom: 10px !important;padding-left: 0px !important;background-color: #dd3333 !important;}.vc_custom_1591034205990{margin-top: 0px !important;border-top-width: 0px !important;padding-top: 0px !important;}.vc_custom_1588798012275{padding-top: 20px !important;padding-right: 20px !important;padding-bottom: 20px !important;padding-left: 20px !important;background-color: #03125b !important;}.vc_custom_1588626423333{margin-left: 0px !important;border-left-width: 0px !important;padding-left: 0px !important;}.vc_custom_1588626531012{margin-right: 0px !important;margin-left: 0px !important;border-right-width: 0px !important;border-left-width: 0px !important;padding-right: 0px !important;padding-left: 0px !important;}.vc_custom_1584231594490{background-color: #e0e0e0 !important;}.vc_custom_1591048126494{padding-right: 20px !important;padding-bottom: 20px !important;padding-left: 20px !important;}.vc_custom_1588668212670{margin-top: 0px !important;margin-right: 0px !important;margin-left: 0px !important;border-top-width: 0px !important;border-right-width: 0px !important;border-left-width: 0px !important;padding-top: 0px !important;padding-right: 0px !important;padding-bottom: 10px !important;padding-left: 0px !important;}.vc_custom_1591048141317{padding-right: 10px !important;padding-bottom: 10px !important;padding-left: 10px !important;}.vc_custom_1588612589118{margin-left: 0px !important;border-left-width: 0px !important;padding-left: 0px !important;}.vc_custom_1588612594247{margin-right: 0px !important;border-right-width: 0px !important;padding-right: 0px !important;}.vc_custom_1591048156581{border-top-width: 5px !important;border-right-width: 5px !important;border-bottom-width: 5px !important;border-left-width: 5px !important;padding-top: 5px !important;padding-right: 5px !important;padding-bottom: 5px !important;padding-left: 5px !important;background-color: rgba(157,210,254,0.29) !important;*background-color: rgb(157,210,254) !important;border-left-color: #002454 !important;border-left-style: solid !important;border-right-color: #002454 !important;border-right-style: solid !important;border-top-color: #002454 !important;border-top-style: solid !important;border-bottom-color: #002454 !important;border-bottom-style: solid !important;border-radius: 3px !important;}.vc_custom_1591048166942{border-top-width: 5px !important;border-right-width: 5px !important;border-bottom-width: 5px !important;border-left-width: 5px !important;padding-top: 5px !important;padding-right: 5px !important;padding-bottom: 5px !important;padding-left: 5px !important;background-color: rgba(157,210,254,0.29) !important;*background-color: rgb(157,210,254) !important;border-left-color: #002454 !important;border-left-style: solid !important;border-righ ...
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="//s.w.org" rel="dns-prefetch"/>
# <link href="https://covid19.lacounty.gov/feed/" rel="alternate" title="COUNTY OF LOS ANGELES » Feed" type="application/rss+xml"/>
# <link href="https://covid19.lacounty.gov/comments/feed/" rel="alternate" title="COUNTY OF LOS ANGELES » Comments Feed" type="application/rss+xml"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
# <meta content="COUNTY OF LOS ANGELES" name="application-name"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="COUNTY OF LOS ANGELES" name="twitter:title"/>
# <meta content="covid19.lacounty.gov" name="twitter:description"/>
# <meta content="https://covid19.lacounty.gov/" name="twitter:url"/>
# <!-- This site uses the Google Analytics by MonsterInsights plugin v7.10.1 - Using Analytics tracking - https://www.monsterinsights.com/ -->
# <script data-cfasync="false" type="text/javascript">
# 	var mi_version         = '7.10.1';
# 	var mi_track_user      = true;
# 	var mi_no_track_reason = '';
#
# 	var disableStr = 'ga-disable-UA-161505461-1';
#
# 	/* Function to detect opted out users */
# 	function __gaTrackerIsOptedOut() {
# 		return document.cookie.indexOf(disableStr + '=true') > -1;
# 	}
#
# 	/* Disable tracking if the opt-out cookie exists. */
# 	if ( __gaTrackerIsOptedOut() ) {
# 		window[disableStr] = true;
# 	}
#
# 	/* Opt-out function */
# 	function __gaTrackerOptout() {
# 	  document.cookie = disableStr + '=true; expires=Thu, 31 Dec 2099 23:59:59 UTC; path=/';
# 	  window[disableStr] = true;
# 	}
#
# 	if ( mi_track_user ) {
# 		(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 			(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 			m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 		})(window,document,'script','//www.google-analytics.com/analytics.js','__gaTracker');
#
# 		__gaTracker('create', 'UA-161505461-1', 'auto');
# 		__gaTracker('set', 'forceSSL', true);
# 		__gaTracker('require', 'displayfeatures');
# 		__gaTracker('send','pageview');
# 	} else {
# 		console.log( "" );
# 		(function() {
# 			/* https://developers.google.com/analytics/devguides/collection/analyticsjs/ */
# 			var noopfn = function() {
# 				return null;
# 			};
# 			var noopnullfn = function() {
# 				return null;
# 			};
# 			var Tracker = function() {
# 				return null;
# 			};
# 			var p = Tracker.prototype;
# 			p.get = noopfn;
# 			p.set = noopfn;
# 			p.send = noopfn;
# 			var __gaTracker = function() {
# 				var len = arguments.length;
# 				if ( len === 0 ) {
# 					return;
# 				}
# 				var f = arguments[len-1];
# 				if ( typeof f !== 'object' || f === null || typeof f.hitCallback !== 'function' ) {
# 					console.log( 'Not running function __gaTracker(' + arguments[0] + " ....) because you are not being tracked. " + mi_no_track_reason );
# 					return;
# 				}
# 				try {
# 					f.hitCallback();
# 				} catch (ex) {
#
# 				}
# 			};
# 			__gaTracker.create = function() {
# 				return new Tracker();
# 			};
# 			__gaTracker.getByName = noopnullfn;
# 			__gaTracker.getAll = function() {
# 				return [];
# 			};
# 			__gaTracker.remove = noopfn;
# 			window['__gaTracker'] = __gaTracker;
# 					})();
# 		}
# </script>
# <!-- / Google Analytics by MonsterInsights -->
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/12.0.0-1\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/12.0.0-1\/svg\/","svgExt":".svg","source":{"concatemoji":"\/\/covid19.lacounty.gov\/wp-includes\/js\/wp-emoji-release.min.js?ver=5.3.2"}};
# 			!function(e,a,t){var r,n,o,i,p=a.createElement("canvas"),s=p.getContext&&p.getContext("2d");function c(e,t){var a=String.fromCharCode;s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,e),0,0);var r=p.toDataURL();return s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,t),0,0),r===p.toDataURL()}function l(e){if(!s||!s.fillText)return!1;switch(s.textBaseline="top",s.font="600 32px Arial",e){case"flag":return!c([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])&&(!c([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!c([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]));case"emoji":return!c([55357,56424,55356,57342,8205,55358,56605,8205,55357,56424,55356,57340],[55357,56424,55356,57342,8203,55358,56605,8203,55357,56424,55356,57340])}return!1}function d(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(i=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},o=0;o<i.length;o++)t.supports[i[o]]=l(i[o]),t.supports.everything=t.supports.everything&&t.supports[i[o]],"flag"!==i[o]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[i[o]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(r=t.source||{}).concatemoji?d(r.concatemoji):r.wpemoji&&r.twemoji&&(d(r.twemoji),d(r.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# <style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link href="//covid19.lacounty.gov/wp-includes/css/dist/block-library/style.min.css?ver=5.3.2" id="wp-block-library-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//covid19.lacounty.gov/wp-content/plugins/cff-extensions/cff-masonry/css/masonry.css?ver=1.1.3" id="cff_masonry_css-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//covid19.lacounty.gov/wp-content/plugins/cff-extensions/cff-carousel/css/carousel.css?ver=1.1" id="cff_carousel_css-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//covid19.lacounty.gov/wp-content/plugins/contact-form-7/includes/css/styles.css?ver=5.1.6" id="contact-form-7-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//covid19.lacounty.gov/wp-content/plugins/custom-facebook-feed-pro/css/cff-style.css?ver=3.6.1" id="cff-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css?ver=5.3.2" id="sb-font-awesome-css-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//covid19.lacounty.gov/wp-content/plugins/custom-twitter-feeds-pro/css/ctf-styles.css?ver=1.5.7" id="ctf_styles-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//covid19.lacounty.gov/wp-content/plugins/ditty-news-ticker/inc/static/libs/fontastic/styles.css?ver=2.2.9" id="ditty-news-ticker-font-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//covid19.lacounty.gov/wp-content/plugins/ditty-news-ticker/inc/static/css/style.css?ver=1589922776" id="ditty-news-ticker-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//covid19.lacounty.gov/wp-content/plugins/inel_elementsbox_plugin/css/elementsbox.css?ver=5.3.2" id="inel-elementsbox-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//covid19.lacounty.gov/wp-content/plugins/inel_elementsbox_plugin/css/font-awesome.css?ver=5.3.2" id="bth-fontawesome-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//covid19.lacounty.gov/wp-content/plugins/inel_elementsbox_plugin/css/elegant-font-icons.css?ver=5.3.2" id="bth-elegant-font-icons-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//covid19.lacounty.gov/wp-content/plugins/inel_elementsbox_plugin/css/themify-icons.css?ver=5.3.2" id="bth-themify-font-icons-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//covid19.lacounty.gov/wp-content/plugins/inel_elementsbox_plugin/css/animate.css?ver=5.3.2" id="inel-animate-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//covid19.lacounty.gov/wp-content/plugins/revslider/public/assets/css/rs6.css?ver=6.1.3" id="rs-plugin-settings-css" media="all" rel="stylesheet" type="text/css"/>
# <style id="rs-plugin-settings-inline-css" type="text/css">
# #rs-demo-id {}
# </style>
# <link href="//covid19.lacounty.gov/wp-content/plugins/wordpress-custom-scrollbar/css/jquery.mCustomScrollbar.min.css?ver=5.3.2" id="wp-custom-scrollbar-main-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//covid19.lacounty.gov/wp-content/plugins/wp-flipclock/inc/css/flipclock.css?ver=5.3.2" id="flipclock-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//covid19.lacounty.gov/wp-content/plugins/wp-flipclock/inc/css/added.css?ver=5.3.2" id="flipclock-added-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//covid19.lacounty.gov/wp-content/themes/blade/css/font-awesome.min.css?ver=4.7.0" id="blade-grve-awesome-fonts-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//covid19.lacounty.gov/wp-content/themes/blade/css/basic.css?ver=3.1.3" id="blade-grve-basic-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//covid19.lacounty.gov/wp-content/themes/blade/css/grid.css?ver=3.1.3" id="blade-grve-grid-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//covid19.lacounty.gov/wp-content/themes/blade/css/theme-style.css?ver=3.1.3" id="blade-grve-theme-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//covid19.lacounty.gov/wp-content/themes/blade/css/elements.css?ver=3.1.3" id="blade-grve-elements-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//covid19.lacounty.gov/wp-content/themes/blade-child/style.css?ver=3.1.3" id="blade-grve-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//covid19.lacounty.gov/wp-content/themes/blade/css/responsive.css?ver=3.1.3" id="blade-grve-responsive-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//covid19.lacounty.gov/wp-content/plugins/easy-tables-vc/assets/css/style.css?ver=1.0.0" id="vc_plugin_table_style_css-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//covid19.lacounty.gov/wp-content/plugins/easy-tables-vc/assets/css/themes.css?ver=5.3.2" id="vc_plugin_themes_css-css" media="all" rel="stylesheet" type="text/css"/>
# <!--[if lt IE 9]>
# <link rel='stylesheet' id='vc_lte_ie9-css'  href='//covid19.lacounty.gov/wp-content/plugins/js_composer/assets/css/vc_lte_ie9.min.css?ver=6.0.5' type='text/css' media='screen' />
# <![endif]-->
# <link href="//covid19.lacounty.gov/wp-content/plugins/vc-elegant-tabs/css/tabstyles.css?ver=5.3.2" id="iw_tab_style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//covid19.lacounty.gov/wp-content/plugins/vc-elegant-tabs/css/animate.min.css?ver=5.3.2" id="iw_tab_aminate-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//covid19.lacounty.gov/wp-content/plugins/vc-elegant-tabs/css/tabs.css?ver=5.3.2" id="iw_tabs-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//covid19.lacounty.gov/wp-content/plugins/vc-elegant-tabs/css/font-awesome.min.css?ver=5.3.2" id="iw_font-awesome-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//covid19.lacounty.gov/wp-content/plugins/js_composer/assets/css/js_composer.min.css?ver=6.0.5" id="js_composer_front-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//fonts.googleapis.com/css?family=Open+Sans%3A400%2C400italic%7CMontserrat%3A700%7CGreat+Vibes%3A400&amp;subset=latin&amp;ver=1590180116" id="redux-google-fonts-grve_blade_options-css" media="all" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
# /* <![CDATA[ */
# var monsterinsights_frontend = {"js_events_tracking":"true","download_extensions":"doc,pdf,ppt,zip,xls,docx,pptx,xlsx","inbound_paths":"[]","home_url":"https:\/\/covid19.lacounty.gov","hash_tracking":"false"};
# /* ]]> */
# </script>
# <script src="//covid19.lacounty.gov/wp-content/plugins/google-analytics-for-wordpress/assets/js/frontend.js?ver=7.10.1" type="text/javascript"></script>
# <script src="//covid19.lacounty.gov/wp-includes/js/jquery/jquery.js?ver=1.12.4-wp" type="text/javascript"></script>
# <script src="//covid19.lacounty.gov/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.4.1" type="text/javascript"></script>
# <script src="//covid19.lacounty.gov/wp-content/plugins/wordpress-custom-scrollbar/js/jquery.mCustomScrollbar.min.js?ver=3.1" type="text/javascript"></script>
# <script src="//covid19.lacounty.gov/wp-content/plugins/wordpress-custom-scrollbar/js/jquery.nicescroll.min.js?ver=3.7" type="text/javascript"></script>
# <script src="//covid19.lacounty.gov/wp-content/plugins/wp-flipclock/inc/js/flipclock.min.js?ver=0.5.5" type="text/javascript"></script>
# <script src="//covid19.lacounty.gov/wp-content/themes/blade/js/modernizr.custom.js?ver=2.8.3" type="text/javascript"></script>
# <link href="https://covid19.lacounty.gov/wp-json/" rel="https://api.w.org/"/>
# <link href="https://covid19.lacounty.gov/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://covid19.lacounty.gov/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <meta content="WordPress 5.3.2" name="generator">
# <link href="https://covid19.lacounty.gov/" rel="canonical"/>
# <link href="https://covid19.lacounty.gov/" rel="shortlink"/>
# <link href="https://covid19.lacounty.gov/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fcovid19.lacounty.gov%2F" rel="alternate" type="application/json+oembed"/>
# <link href="https://covid19.lacounty.gov/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fcovid19.lacounty.gov%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
# <!-- start Simple Custom CSS and JS -->
# <style type="text/css">
# .goog-logo-link {
#    display:none !important;
# }
#
# .goog-te-gadget {
#    color: transparent !important;
# }
#
# .goog-te-gadget .goog-te-combo {
#    color: #9ca1a8 !important;
# }
#
# #grve-top-bar ul.grve-left-side {
#     float: left;
#     text-align: left;
#     width: 50%;
# 	padding-top: 15px;
# }
#
# #grve-top-bar ul.grve-right-side {
#     float: right;
#     text-align: right;
#     width: 50%;
#     margin-bottom: -18px;
#   	padding-top: 2px;
# }
# </style>
# <!-- end Simple Custom CSS and JS -->
# <!-- start Simple Custom CSS and JS -->
# <style type="text/css">
#
# #grve-main-content li {
#   margin-bottom: 0.5em;
# }
# #grve-main-content table,
# #grve-main-content table tr,
# #grve-main-content table tr td {
#   text-align: left;
#   border: none;
# }</style>
# <!-- end Simple Custom CSS and JS -->
# <!-- start Simple Custom CSS and JS -->
# <style type="text/css">
#
# /* Inverted Class (Optional) */
# #grve-theme-wrapper .inverted p,
# #grve-theme-wrapper .inverted ul,
# #grve-theme-wrapper .inverted li,
# #grve-theme-wrapper .inverted a:link,
# #grve-theme-wrapper .inverted a:hover {
#   color: #fff !important;
# }
# #grve-theme-wrapper .inverted a:hover {
#   text-decoration: underline;
# }
# #grve-theme-wrapper .inverted h3 {
#   color: #68ba86 !important;
# }
#
# /* Table with Icons (Optional) */
# .table-with-icons table,
# .table-with-icons table tr {
#   border: none;
# }
# .table-with-icons table td {
#   text-align: left;
#   padding-left: 30px;
#   border: none;
# }
# .table-with-icons table td img {
#   margin-left: -30px;
#   float: left;
# }
# body.admin-bar .vc_empty_space {
#   background: red;
# }
#
# /* Extra Padding (Optional) */
# #grve-theme-wrapper .extra-padding {
#   padding-top: 120px;
#   padding-bottom: 120px;
# }
#
# /* Home Slider */
# @media (min-width: 1024px) {
#   body.home .rev_slider_wrapper .tp-bgimg {
#     background-size: 74% auto !important;
#   }
# }
#
# /* District Board Supervisors */
#
#
# /* Seals of LA County */
# #grve-main-content .seals {
#   text-align: center;
# }
# #grve-main-content .seals a {
#   display: inline-block;
#   -moz-transform: scale(0.8);
#   -webkit-transform: scale(0.8);
#   -ms-transform: scale(0.8);
#   transform: scale(0.8);
# }</style>
# <!-- end Simple Custom CSS and JS -->
# <!-- start Simple Custom CSS and JS -->
# <style type="text/css">
# /* Footer Margin */
#
# #grve-footer {
#   margin-top: 60px;
# }
#
# </style>
# <!-- end Simple Custom CSS and JS -->
# <!-- start Simple Custom CSS and JS -->
# <style type="text/css">
# body.admin-bar .vc_empty_space {
#     background: red;
#     background-image: initial;
#     background-position-x: initial;
#     background-position-y: initial;
#     background-size: initial;
#     background-repeat-x: initial;
#     background-repeat-y: initial;
#     background-attachment: initial;
#     background-origin: initial;
#     background-clip: initial;
#     background-color: white;
# }</style>
# <!-- end Simple Custom CSS and JS -->
# <!-- start Simple Custom CSS and JS -->
# <style type="text/css">
# /* Color Overrides */
#
# #grve-main-content .et-tabs nav ul li:nth-child(1) {
#   background-color: #4073ad !important;
# }
# #grve-main-content .et-tabs nav ul li:nth-child(2) {
#   background-color: #c6615f !important;
# }
# #grve-main-content .et-tabs nav ul li:nth-child(3) {
#   background-color: #70ac6e !important;
# }</style>
# <!-- end Simple Custom CSS and JS -->
# <!-- start Simple Custom CSS and JS -->
# <style type="text/css">
#
# /* Board of District Supervisors */
# #grve-main-content .custom-district-row {
#   background: 100% 0 no-repeat #fff;
#   width: 100%;
#   display: table;
#   position: relative;
# }
# #grve-main-content .custom-district-1 {
#   background-image: url(/wp-content/uploads/district-1.jpg);
# }
# #grve-main-content .custom-district-2 {
#   background-image: url(/wp-content/uploads/district-2.jpg);
# }
# #grve-main-content .custom-district-3 {
#   background-image: url(/wp-content/uploads/district-3.jpg);
# }
# #grve-main-content .custom-district-4 {
#   background-image: url(/wp-content/uploads/district-4.jpg);
# }
# #grve-main-content .custom-district-5 {
#   background-image: url(/wp-content/uploads/district-5.jpg);
# }
# #grve-main-content .custom-district-row .grve-column {
#   width: 58%;
#   padding: 0;
#   position: absolute;
#   top: 0;
#   left: calc(25% + 5px);
#   right: calc(25% + 5px);
#   bottom: 5px;
# }
# #grve-main-content .custom-district-row .grve-column:first-of-type {
#   width: 25%;
#   position: relative;
#   left: 0;
# }
# #grve-main-content .custom-district-row .grve-column:last-of-type {
#   width: calc(17% - 15px);
#   /* position: relative; */
#   left: auto;
#   right: 5px;
#   bottom: 5px;
# }
# #grve-main-content .custom-district-row .grve-column .grve-element {
#   /* position: absolute; */
# }
# #grve-main-content .custom-district-row .grve-column:first-of-type .grve-image {
#   position: relative;
# }
# #grve-main-content .custom-district-row .grve-column:first-of-type .grve-image img {
#   padding: 5px 0 5px 5px;
# }
# #grve-main-content .custom-district-row .grve-column .grve-text h1 {
#   color: rgba(40,143,208,.9) !important;
#   font-weight: 300;
#   font-size: 30px !important;
#   padding: 10% 0 0 7.5%;
#   margin-bottom: 8px;
#   display: block;
# }
# #grve-main-content .custom-district-row .grve-column .grve-text .district-name {
#   color: rgba(40,143,208,.9);
#   font-style: italic;
#   font-size: 18px;
#   line-height: 1em;
#   padding: 0 0 0 7.5%;
#   margin: 0;
# }
# #grve-main-content .custom-district-row .grve-column .custom-supervisor-info {
#   background-color: rgba(40,143,208,.9);
#   height: 50%;
#   position: absolute;
#   left: 0;
#   right: 0;
#   bottom: 0;
# }
# #grve-main-content .custom-district-row .grve-column .custom-supervisor-info p {
#   color: #fff;
#   line-height: 2em !important;
#   padding: 0;
#   margin: 0 !important;
# }
# #grve-main-content .custom-district-row .grve-column .custom-supervisor-info div {
#   float: left;
#   margin-top: 10px;
#   margin-left: 6%;
# }
# #grve-main-content .custom-district-row .grve-column .custom-supervisor-info a:link,
# #grve-main-content .custom-district-row .grve-column .custom-supervisor-info a:visited {
#   color: #fff;
#   line-height: 2em !important;
#   padding: 0;
#   display: inline-block;
# }
# @media (max-width: 1160px) {
#   #grve-main-content .custom-district-row .grve-column .custom-supervisor-info p,
#   #grve-main-content .custom-district-row .grve-column .custom-supervisor-info a:link,
#   #grve-main-content .custom-district-row .grve-column .custom-supervisor-info a:visited {
#     line-height: 22px !important;
#   }
# }
# #grve-main-content .custom-district-row .grve-column .custom-supervisor-info a:hover {
#   opacity: 1;
# }
# #grve-main-content .custom-district-row .grve-column .custom-supervisor-info a:active {
#   opacity: 1;
# }
# #grve-main-content .custom-district-row .grve-column .custom-supervisor-info p span.fa,
# #grve-main-content .custom-district-row .grve-column .custom-supervisor-info a span.fa {
#   text-align: center;
#   color: rgba(255,255,255,0.6);
#   width: 2.5em;
# }
# #grve-main-content .custom-district-row .grve-column:last-of-type .grve-element {
#   position: absolute;
#   top: 0;
#   left: 0;
#   right: 0;
#   bottom: 0;
# }
# #grve-main-content .custom-district-row .grve-column:last-of-type .grve-btn {
#   background-color: rgba(40,143,208,.9);
#   font-weight: 300 !important;
#   font-size: 20px !important;
#   font-family: 'Open Sans',sans-serif !important;
#   text-transform: none;
#   height: 50%;
#   padding: 0;
#   position: absolute;
#   right: 0;
#   bottom: 0;
# }
# #grve-main-content .custom-district-row .grve-column:last-of-type .grve-btn span {
#   line-height: 1em;
#   height: 1em;
#   position: absolute;
#   left: 10px;
#   bottom: 10px;
# }
# #grve-main-content .custom-district-row .grve-column:last-of-type .grve-btn:before {
#   font: normal normal normal 14px/1 FontAwesome;
#   content: "\f041";
#   font-size: 2.5em;
#   text-rendering: auto;
#   -webkit-font-smoothing: antialiased;
#   position: absolute;
#   top: 10px;
#   right: 10px;
# }
# @media (min-width: 960px) and (max-width: 1090px) {
#   #grve-main-content .custom-district-row .grve-column .custom-supervisor-info {
#     letter-spacing: 0;
#   }
# }
# @media (min-width: 960px) and (max-width: 1050px) {
#   #grve-main-content .custom-district-row .grve-column .custom-supervisor-info div {
#     margin-left: 5px;
#   }
# }
# @media (max-width: 959px) {
#   #grve-main-content .custom-district-row {
#     background-image: none !important;
#     padding: 0;
#     padding-bottom: 5px !important;
#     position: static;
#   }
#   #grve-main-content .custom-district-row .grve-column {
#     margin: 0;
#     width: auto;
#     height: auto;
#     display: block;
#     float: none;
#     position: static;
#     top: auto;
#     left: auto !important;
#     right: auto !important;
#     bottom: auto !important;
#   }
#   #grve-main-content .custom-district-row .grve-column:first-of-type {
#     margin-bottom: 0;
#     float: left;
#   }
#   #grve-main-content .custom-district-row .grve-column:first-of-type .grve-image img {
#     padding: 0;
#   }
#   #grve-main-content .custom-district-row .grve-column .grve-element {
#     margin: 5px 5px 0 5px;
#     display: block;
#     position: static;
#   }
#   #grve-main-content .custom-district-row .grve-column .grve-text h1,
#   #grve-main-content .custom-district-row .grve-column .grve-text .district-name {
#     margin-left: 30%;
#   }
#   #grve-main-content .custom-district-row .grve-column .custom-supervisor-info {
#     padding-bottom: 10px;
#   }
#   #grve-main-content .custom-district-row .grve-column .grve-element:after {
#     content: "";
#     padding: 0;
#     display: block;
#     clear: both;
#     position: static;
#   }
#   #grve-main-content .custom-district-row .grve-column:last-of-type {
#     width: auto !important;
#   }
#   #grve-main-content .custom-district-row .grve-column:last-of-type .grve-element {
#     width: auto;
#     height: auto;
#     float: none;
#     clear: both;
#     display: block;
#     position: static;
#   }
#   #grve-main-content .custom-district-row .grve-column:last-of-type .grve-element a.grve-btn {
#     line-height: 48px;
#     text-align: left;
#     width: auto;
#     height: auto;
#     display: block;
#     float: none;
#     clear: both;
#     position: relative;
#   }
#   #grve-main-content .custom-district-row .grve-column:last-of-type .grve-btn:before {
#     position: absolute;
#   }
#   #grve-main-content .custom-district-row .grve-column:last-of-type .grve-btn span {
#     margin-left: calc(7% + 5px);
#     position: static;
#   }
#   #grve-main-content .custom-district-row .grve-column:last-of-type .grve-btn:before {
#     font-size: 38px;
#     top: 5px;
#   }
# }
# @media (max-width: 767px) {
#   #grve-main-content .custom-district-row .grve-column .grve-text h1,
#   #grve-main-content .custom-district-row .grve-column .grve-text .district-name {
#     margin-left: 25%;
#   }
# }</style>
# <!-- end Simple Custom CSS and JS -->
# <!-- start Simple Custom CSS and JS -->
# <style type="text/css">
# /* Adjust navigation button position for responsive */
#
# /*@media only screen and (min-width: 1024px) and (max-width: 1200px) {
#
#   .tp-bullets {
#     margin-left: 200px;
#   }
# }
#
# @media only screen and (min-width: 768px) and (max-width: 1023px) {
#
#   .tp-bullets {
#     margin-left: 200px;
#   }
# }
#
# @media only screen and (min-width: 480px) and  (max-width: 767px) {
#
#   .tp-bullets {
#     margin-left: -350px;
#   }
# }
#
# @media only screen and (max-width: 479px) {
#
#   .tp-bullets {
#     margin-left: -265px;
#   }
# }*/
# </style>
# <!-- end Simple Custom CSS and JS -->
# <!-- start Simple Custom CSS and JS -->
# <style type="text/css">
#
# /* Alignment Classes */
# @media (min-width: 1001px) {
#   #grve-main-content .alignleft {
#     width: 50%;
#     margin-right: 20px;
#     float: left;
#   }
#   #grve-main-content .alignright {
#     width: 50%;
#     margin-left: 20px;
#     float: right;
#   }
# }
# @media (max-width: 1000px) {
#   #grve-main-content .alignleft {
#     width: 100%;
#     margin-left: 0;
#     margin-right: 0;
#     float: none;
#   }
#   #grve-main-content .alignright {
#     width: 100%;
#     margin-left: 0;
#     margin-right: 0;
#     float: none;
#   }
# }
#
# /* Icon Box Fix */
# #grve-main-content .inel_iconbox_icon.inel_iconbox_icon_size_96 {
#   padding: 0;
# }
#
# /* Pagination Tabs */
# .grve-pagination ul {
#   margin-bottom: 30px;
# }
#
# /* Main Menu */
# #grve-header #grve-main-menu .grve-wrapper > ul > li > a {
#   line-height: 20px;
#   padding-top: 19px;
#   padding-bottom: 28px;
# }
# #grve-header #grve-main-menu .grve-wrapper > ul {
#   padding-top: 40px;
# }
# #grve-header.grve-sticky-header.grve-shrink #grve-main-menu .grve-wrapper > ul > li > a {
#   line-height: 20px !important;
#   padding-top: 19px;
#   padding-bottom: 28px;
# }
# #grve-main-menu.grve-sticky-header.grve-shrink #grve-main-menu .grve-wrapper > ul {
#   padding-top: 20px;
# }
#
# /* Page Height Fixes */
# #grve-content {
#   min-height: calc(100vh - 261px);
# }
# #grve-post-breadcrumbs + .grve-single-wrapper #grve-content,
# #grve-page-breadcrumbs + #grve-content {
#   min-height: calc(100vh - 331px);
# }
# .grve-image a {
#   display: block;
# }
# #grve-main-content #grve-content .grve-feature-header {
#   margin-top: 0 !important;
# }
# #grve-main-content .grve-main-content-wrapper {
#   padding: 0 !important;
# }
# #grve-content #grve-main-content .grve-feature-header {
#   margin-top: 0 !important;
# }
# #grve-content #grve-main-content .grve-feature-footer {
#   margin-bottom: 0 !important;
# }
# #grve-header.grve-overlapping + #grve-content {
#   top: 0 !important;
#   margin-bottom: 0 !important;
# }
# </style>
# <!-- end Simple Custom CSS and JS -->
# <!-- start Simple Custom CSS and JS -->
# <style type="text/css">
#
# /* Drop Menu Widths */
# #grve-header #grve-main-menu .grve-wrapper > ul > li > a.dd-residents + ul.sub-menu {
# /*   width: 250px !important; */
# }
# #grve-header #grve-main-menu .grve-wrapper > ul > li > a.dd-government + ul.sub-menu {
#   width: 390px !important;
# }
# #grve-header #grve-main-menu .grve-wrapper > ul > li > a.dd-business + ul.sub-menu {
#   width: 380px !important;
# }
# #grve-header #grve-main-menu .grve-wrapper > ul > li > a.dd-things-to-do + ul.sub-menu {
#   width: 280px !important;
# }
# #grve-header #grve-main-menu .grve-wrapper > ul > li > a.dd-emergency + ul.sub-menu {
#   width: 380px !important;
# }
#
# /* Responsive Select Box Height */
# #grve-theme-wrapper select {
#   min-height: 44px !important;
# }</style>
# <!-- end Simple Custom CSS and JS -->
# <!-- start Simple Custom CSS and JS -->
# <style type="text/css">
# /* Google translate */
#
# .goog-te-gadget-simple {
#   background-color: transparent !important;
#   border: none !important;
# }
#
# .goog-te-gadget-simple img {
#   display: none !important;
# }
#
# .goog-te-menu-value span {
#   border: none !important;
#   color: #ffffff !important;
# }
#
# .goog-te-menu-value span:first-child,
# .goog-te-menu-value span:nth-child(2) {
#   display: none;
# }
#
# .menu-item span.fa-globe {
#   float: left;
#   display: inline;
#   padding-right: 0;
#   padding-left: 5px;
# }
#
# .goog-te-menu-value span:nth-child(3)::before {
#   content: "Translate ";
# }</style>
# <!-- end Simple Custom CSS and JS -->
# <!-- start Simple Custom CSS and JS -->
# <style type="text/css">
# .header-social {
#     float: right;
#     height: 35px;
# 	margin-right:-30px;
# }
#
# .header-social .sharethis {
#     display: none
# }
#
# i.icon {
#     font-family: FontAwesome;
#     font-style: normal;
#     padding-right: 5px;
#     display: inline-block
# }
#
# .footer_livechat {
#     float: right;
#     color: #fff;
#     font-size: 14px;
#     font-weight: 400;
#     opacity: .7;
# /*    min-width: 130px; */
#     min-height: 1px;
#     display: block;
#     text-transform: uppercase
# }
#
# .footer_livechat a {
#     color: #fff;
#     text-decoration: none
# }
#
# .footer_livechat a span {
#     display: none
# }
#
# .footer_livechat a span.online {
#     display: block
# }
#
# .footer_livechat .offline .fa-commenting-o,
# .footer_livechat .offline .status {
#     color: #FF7F00
# }
#
# .footer_livechat .fa-commenting-o {
#     font-size: 42px;
#     color: #08F656;
#     display: block;
#     float: left;
#     margin: -1px 6px 0 10px;
# }
#
# .footer_livechat .status {
#     display: block;
#     font-size: 14px;
#     margin-top: -2px;
#     white-space: nowrap;
#     text-transform: capitalize
# }
#
# .footer_livechat .status.off {
#     color: #FF7F00
# }
#
# .footer_livechat:hover {
#     text-decoration: none;
#     color: #fff;
#     opacity: 1
# }
#
# .sharethis {
#     float: right;
#     margin: 7px 0 0
# }
#
# .sharethis.share-content-hidetitle {
#     margin-top: -25px
# }
#
# .sharethis a {
#     color: #fff;
#     opacity: .7;
#     margin: 0 2px
# }
#
# .sharethis a:hover {
#     opacity: 1
# }
#
# .sharethis a em {
#     display: none
# }
#
# .sharethis .fa {
#     font-size: 22px;
#     color: #fff
# }
#
# .share-content a .fa,
# .share-content-supervisor a .fa {
#     color: #000
# }
#
# .share-content-supervisor {
#     position: absolute;
#     top: 0;
#     right: 0;
#     z-index: 9999;
#     margin-top: -25px
# }
#
# .footer_open_menu a {
#     display: block;
#     font-size: 13px;
#     font-weight: 300;
#     color: #6CBFE5
# }
#
# ul.letters-nav {
#     list-style: none;
#     padding: 0;
#     display: block;
#     clear: both
# }
#
# ul.letters-nav li {
#     float: left;
#     border-right: 1px solid #bbb;
#     text-align: center;
#     margin-bottom: 2px
# }
#
# ul.letters-nav li:last-child {
#     border: none
# }
#
# ul.letters-nav li a {
#     padding: 0 10px;
#     width: 30px;
#     display: block
# }
#
# ul.letters-nav li a.active {
#     background: #4881c2;
#     color: #FFF
# }
#
# .page-breadcrumbs-wrapper {
#     color: #fff;
#     background: rgba(0, 0, 0, .6);
#     width: auto;
#     padding: 5px 10px;
#     margin-bottom: 3px;
#     font-weight: 300;
#     display: inline-block;
#     font-size: 14px
# }
#
# .page-breadcrumbs-wrapper a {
#     color: #fff;
#     padding: 0 10px;
#     opacity: .8
# }
#
# .page-breadcrumbs-wrapper a:hover {
#     opacity: 1;
#     text-decoration: none
# }
#
# .page-breadcrumbs-wrapper .current-page {
#     padding: 0 10px;
#     opacity: .6
# }
#
# @media (max-width:1200px) and (min-width:768px) {
#     ul.navbar li a {
#         margin: 0 10px
#     }
#     .searchbox {
#         width: 315px
#     }
#     .searchbox .searchbox_input {
#         width: 300px
#     }
# }
#
# @media (min-width:1400px) {
#     ul.navbar {
#         margin-top: 48px;
#         margin-left: 30px
#     }
#     .header-social,
#     .searchbox {
#         margin-top: 28px
#     }
# }
#
# @media (min-width:1200px) and (max-width:1400px) {
#     ul.navbar {
#         margin-left: 30px
#     }
# }
#
# @media (max-width:1200px) {
#     header .container {
#         position: relative
#     }
#     .header-social {
#         margin-top: 10px
#     }
# }
#
# @media (max-width:992px) {
#     .footer ul.footer_mainmenu {
#         float: none;
#         margin: 0 auto;
#         width: auto;
#         text-align: center;
#         padding-left: 15px
#     }
#     .footer ul.footer_mainmenu li {
#         display: inline-block;
#         float: none
#     }
#     .footer ul.footer_mainmenu li a {
#         display: inline-block
#     }
#     .footer .footer_box .footer_logo {
#         display: none
#     }
#     .footer .footer_box .footer_left {
#         float: none
#     }
#     .footer .footer_box .footer_left ul.footer_secmenu {
#         float: none;
#         text-align: center;
#         margin-top: 10px
#     }
#     .footer .footer_box .footer_left ul.footer_secmenu li {
#         display: inline-block;
#         float: none
#     }
#     .footer .footer_box .footer_right {
#         float: none;
#         margin-top: 10px
#     }
#     .footer .footer_box .footer_right .pull-right {
#         float: none!important
#     }
#     .footer .footer_box .footer_right ul.footer_secmenu {
#         padding: 0;
#         float: none;
#         text-align: center;
#         margin: 10px auto 0
#     }
#     .footer .footer_box .footer_right ul.footer_secmenu li {
#         display: inline-block;
#         float: none
#     }
# }
#
# @media (min-width:768px) and (max-width:992px) {
#     ul.navbar {
#         margin-left: -25px
#     }
#     ul.navbar li a {
#         font-size: 19px;
#         margin: 0 15px
#     }
# }
#
# @media (max-width:767px) {
#     .sharethis.share-content.share-content-hidetitle {
#         float: none;
#         display: block;
#         margin: 0 0 10px;
#         height: 25px
#     }
#     .header-social .footer_livechat .fa-commenting-o,
#     ul.navbar li a.active span {
#         display: none
#     }
#     .sharethis.share-content.share-content-hidetitle .addthis_toolbox {
#         float: right
#     }
#     .header-social {
#         position: absolute;
#         top: 5px;
#         right: 55px
#     }
#     .header-social .footer_livechat {
#         min-width: 0;
#         font-size: 12px
#     }
#     ul.navbar,
#     ul.navbar li {
#         float: none
#     }
#     ul.navbar li a {
#         padding: 4px;
#         text-shadow: none;
#         font-size: 15px
#     }
#     ul.navbar li a.active {
#         background: 0 0
#     }
# }
#
# @media (max-width:560px) {
#     .footer ul.footer_mainmenu li {
#         border-right: 1px solid #999
#     }
#     .footer ul.footer_mainmenu li a {
#         margin: 0 5px
#     }
#     .footer ul.footer_mainmenu li a i {
#         display: none!important
#     }
#     .footer .footer_livechat,
#     .footer .sharethis,
#     .footer .twitter {
#         float: left;
#         margin: 10px 20px 0 0
#     }
#     .footer .footer_livechat {
#         clear: both;
#         margin: 10px 20px 0 0;
#         min-width: 0
#     }
# }
#
# @media (max-width:330px) {
#     ul.footer_mainmenu {
#         list-style: none;
#         float: left;
#         margin: 0 15px 20px -10px;
#         padding: 0
#     }
#     ul.footer_mainmenu li a {
#         display: block;
#         color: #fff;
#         font-size: .813em
#     }
#     .footer_livechat {
#         min-width: 0
#     }
#     .footer_livechat i {
#         display: none!important
#     }
# }
#
# .home-main-tab {
#     width: 100%;
#     margin: 0;
#     padding: 0
# }</style>
# <!-- end Simple Custom CSS and JS -->
# <!-- start Simple Custom CSS and JS -->
# <style type="text/css">
# .ajde_evcal_calendar #evcal_head.calendar_header #evcal_cur, .ajde_evcal_calendar .evcal_month_line p {
#     color: #e67019;
# }
#
# .evo_cal_above span.evo-gototoday-btn {
#     color: #ffffff;
#     background-color: #e67019;
# }
#
# #evcal_list .eventon_list_event .evcal_desc span.evcal_event_title, .ajde_evcal_calendar.boxy.boxstyle1 #evcal_list .eventon_list_event .evcal_desc span.evcal_event_title, .evo_lightboxes .evo_pop_body .evcal_desc span.evcal_desc2 {
#     color: #4d97b2;
# }
#
# #evcal_list .eventon_list_event .evcal_eventcard p, .ajde_evcal_calendar .eventon_events_list .eventon_desc_in ul, .evo_lightboxes .evo_pop_body .evcal_evdata_row .evcal_evdata_cell p, .evo_lightboxes .evcal_evdata_cell p a {
#     color: #000000;
# }</style>
# <!-- end Simple Custom CSS and JS -->
# <!-- start Simple Custom CSS and JS -->
# <style type="text/css">
# /* County departments and principal administration portraits */
#
# .custom-portrait-small {
#   width: 120px;
#   height: auto;
# }</style>
# <!-- end Simple Custom CSS and JS -->
# <!-- start Simple Custom CSS and JS -->
# <style type="text/css">
#
# /* Newsroom Post Entries */
# .custom-newsroom-post .post {
#   margin-bottom: 10px;
#   padding: 30px;
#   background-color: #ffffff !important;
# }
# .custom-newsroom-post .grve-post-content {
#   padding-top: 0;
#   padding-bottom: 0;
# }
# .grve-pagination {
#   padding-top: 20px;
# }
#
# /* Newsroom Posts */
# .category-newsroom .grve-bookmark > .grve-column > .grve-row:last-of-type {
#   padding-bottom: 40px;
#   margin-bottom: 80px;
# }
#
# /* Newsroom Images */
# .category-newsroom img.alignnone {
#   width: 100%;
# }
#
# /* Change Blade styles for accessibility */
# .grve-pagination ul li .grve-icon-arrow-right,
# .grve-pagination ul li .grve-icon-arrow-left {
#   padding-right: 0 !important;
#   padding-left: 0 !important;
#   opacity: 1.0 !important;
#   font-size: 0.750em !important;
# }
#
# .page-numbers li .page-numbers {
#   padding-right: 15px !important;
#   padding-left: 15px !important;
#   opacity: 1;
#   background-color: #ffffff;
#   color: #4073ad;
# }
#
# .page-numbers li .current {
#   background-color: #4073ad;
#   color: #ffffff !important;
# }
#
# .custom-newsroom-bkg-colors-1 .grve-column-1-2:first-child,
# .custom-newsroom-bkg-colors-2 .grve-column-1-2:nth-child(2) {
#   background-color: #c6acc7;
# }
#
# .custom-newsroom-bkg-colors-1 .grve-column-1-2:nth-child(2),
# .custom-newsroom-bkg-colors-2 .grve-column-1-2:first-child {
#   background-color: #cec8d2;
# }
#
# @media only screen and (min-width: 1024px) {
#
#   .custom-newsroom-post .grve-media {
#     width: 34%;
#     padding-right: 30px;
#   }
#
#   .custom-newsroom-bkg-colors-1 .grve-column-1-2,
#   .custom-newsroom-bkg-colors-2 .grve-column-1-2 {
#     min-height: 420px;
#     padding-top: 20px;
#     padding-bottom: 20px;
#   }
# }
#
# @media only screen and (max-width: 1023px) {
#
#   .custom-newsroom-post .grve-media {
#     width: 100%;
#     padding-right: 0;
#   }
# }
#
# @media only screen and (min-width: 768px) and (max-width: 1023px)  {
#
#   .custom-newsroom-bkg-colors-1 .grve-column-1-2,
#   .custom-newsroom-bkg-colors-2 .grve-column-1-2 {
#     min-height: 620px;
#     padding-top: 20px;
#     padding-bottom: 20px;
#   }
# }
#
# @media only screen and (max-width: 767px) {
#
#   .custom-newsroom-post .grve-read-more span {
#     font-size: 13px !important;
#   }
#
#   .custom-newsroom-bkg-colors-1 .grve-text,
#   .custom-newsroom-bkg-colors-2 .grve-text {
#     padding-top: 20px;
#     padding-right: 20px;
#     padding-left: 20px;
#   }
#
#   .custom-newsroom-bkg-colors-1 .grve-column-1-2:first-child,
#   .custom-newsroom-bkg-colors-2 .grve-column-1-2:first-child {
#     background-color: #c6acc7;
#   }
#
#   .custom-newsroom-bkg-colors-2 .grve-column-1-2:nth-child(2),
#   .custom-newsroom-bkg-colors-1 .grve-column-1-2:nth-child(2) {
#     background-color: #cec8d2;
#   }
# }
#
# @media only screen and (min-width: 520px) {
#
#   /* Newsroom with elegant tabs */
#   .post-13709 .et-content-wrap {
#     padding-bottom: 32px;
#     background-color: transparent;
#     border-bottom: 4px solid #2a90da;
#   }
#
# }
#
# @media only screen and (min-width: 480px) {
#
#   .custom-newsroom-post .grve-h2 {
#     margin-bottom: 12px;
#     line-height: 26px;
#     font-size: 24px !important;
#     font-weight: normal;
#   }
# }
#
# @media only screen and (max-width: 479px) {
#
#   .custom-newsroom-post .grve-h2 {
#     margin-bottom: 12px;
#     line-height: 24px;
#     font-size: 20px !important;
#     font-weight: normal;
#   }
# }</style>
# <!-- end Simple Custom CSS and JS -->
# <!-- start Simple Custom CSS and JS -->
# <style type="text/css">
# /* */
#
# .search-results,
# .search-no-results,
# .error404 {
#   background-image: url("/wp-content/uploads/2017/01/Main_Bkg_Poppies.jpg");
#   background-repeat: no-repeat;
#   background-color: #0e1a26 !important;
# }
#
# .search-results .grve-page-title,
# .search-no-results .grve-page-title {
#   width: 100%;
#   margin-right: 0;
#   background-color: transparent !important;
# }
#
# .search-results .grve-content .grve-container,
# .search-no-results .grve-content .grve-container {
#   padding: 15px 0 !important;
#   background: rgba(18, 31, 50, 0.8) !important;
# }
#
# .search-results .grve-section,
# .search-no-results .grve-section,
# .error404 .grve-section {
#   background-color: transparent !important;
# }
#
# .search-results .grve-filter {
#   text-align: center;
# }
#
# .search-results .grve-post-content {
#   padding: 25px 15px 35px 15px;
#   background-color: #ffffff;
# }
#
# .search-no-results .grve-post-content {
#   padding: 40px 15px 50px 15px;
#   background-color: #ffffff;
# }
#
# .search-results .grve-pagination {
#   background: rgba(18, 31, 50, 0.8) !important;
# }
#
# .search-results .page-numbers {
#   color: #ffffff;
# }
#
# .search-results .grve-footer-bar,
# .search-no-results .grve-footer-bar {
#   display: none;
# }
#
# .error404 .grve-section {
#   padding-top: 20% !important;
# }
#
# .error404 .grve-container {
#   padding-top: 80px;
#   padding-bottom: 100px;
#   background-color: rgba(255, 255, 255, 0.8);
# }
#
# .error404 h3 {
#   font-size: 44px !important;
# }
#
# @media only screen and (min-width: 768px) {
#
#   .search-results .grve-main-content-wrapper,
#   .search-no-results .grve-main-content-wrapper {
#     min-height: 930px;
#     padding-top: 15px !important;
#   }
# }
#
# @media only screen and (max-width: 767px) {
# ...
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-24326"><a href="https://facebook.com/countyofla"><span class="grve-item">Facebook</span></a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-24332"><a href="https://instagram.com/countyofla"><span class="grve-item">Instagram</span></a></li>
# </ul>
# </li>
# </ul> </div>
# </div>
# </div>
# </nav>
# <!-- END HIDDEN MENU -->
# <!-- CART AREA -->
# <!-- END CART AREA -->
# <div class="grve-modal" id="grve-search-modal">
# <div class="grve-modal-wrapper">
# <div class="grve-modal-content">
# <div class="grve-modal-item">
# <form action="https://covid19.lacounty.gov/" class="grve-search" method="get"> <button class="grve-search-btn grve-custom-btn grve-text-primary-1" type="submit"><i class="grve-icon-search"></i></button> <input autocomplete="off" class="grve-search-textfield grve-h1" name="s" placeholder="Search for ..." type="text" value=""/></form> </div>
# </div>
# </div>
# </div>
# <div class="grve-modal" id="grve-top-left-form-modal">
# <div class="grve-modal-wrapper">
# <div class="grve-modal-content">
# <div class="grve-modal-form">
# <div class="grve-modal-item">
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grve-modal" id="grve-top-right-form-modal">
# <div class="grve-modal-wrapper">
# <div class="grve-modal-content">
# <div class="grve-modal-form">
# <div class="grve-modal-item">
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grve-modal" id="grve-menu-form-modal">
# <div class="grve-modal-wrapper">
# <div class="grve-modal-content">
# <div class="grve-modal-form">
# <div class="grve-modal-item">
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grve-modal" id="grve-language-modal">
# <div class="grve-modal-wrapper">
# <div class="grve-modal-content">
# <div class="grve-modal-item">
# <ul class="grve-language">
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="grve-back-top">
# <i class="grve-icon-arrow-top-alt grve-text-grey"></i>
# </div>
# </div> <!-- end #grve-theme-wrapper -->
# <!-- MS-CHK --><link href="https://fonts.googleapis.com/css?family=Roboto:700%2C400%2C500" media="all" property="stylesheet" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
# 		if(typeof revslider_showDoubleJqueryError === "undefined") {
# 			function revslider_showDoubleJqueryError(sliderID) {
# 				var err = "<div class='rs_error_message_box'>";
# 				err += "<div class='rs_error_message_oops'>Oops...</div>";
# 				err += "<div class='rs_error_message_content'>";
# 				err += "You have some jquery.js library include that comes after the Slider Revolution files js inclusion.<br>";
# 				err += "To fix this, you can:<br>&nbsp;&nbsp;&nbsp; 1. Set 'Module General Options' ->  'jQuery & OutPut Filters' -> 'Put JS to Body' to on";
# 				err += "<br>&nbsp;&nbsp;&nbsp; 2. Find the double jQuery.js inclusion and remove it";
# 				err += "</div>";
# 			err += "</div>";
# 				jQuery(sliderID).show().html(err);
# 			}
# 		}
# 		</script>
# <script type="text/javascript">
# 		if(typeof revslider_showDoubleJqueryError === "undefined") {
# 			function revslider_showDoubleJqueryError(sliderID) {
# 				var err = "<div class='rs_error_message_box'>";
# 				err += "<div class='rs_error_message_oops'>Oops...</div>";
# 				err += "<div class='rs_error_message_content'>";
# 				err += "You have some jquery.js library include that comes after the Slider Revolution files js inclusion.<br>";
# 				err += "To fix this, you can:<br>&nbsp;&nbsp;&nbsp; 1. Set 'Module General Options' ->  'jQuery & OutPut Filters' -> 'Put JS to Body' to on";
# 				err += "<br>&nbsp;&nbsp;&nbsp; 2. Find the double jQuery.js inclusion and remove it";
# 				err += "</div>";
# 			err += "</div>";
# 				jQuery(sliderID).show().html(err);
# 			}
# 		}
# 		</script>
# <script type="text/javascript">
# 		if(typeof revslider_showDoubleJqueryError === "undefined") {
# 			function revslider_showDoubleJqueryError(sliderID) {
# 				var err = "<div class='rs_error_message_box'>";
# 				err += "<div class='rs_error_message_oops'>Oops...</div>";
# 				err += "<div class='rs_error_message_content'>";
# 				err += "You have some jquery.js library include that comes after the Slider Revolution files js inclusion.<br>";
# 				err += "To fix this, you can:<br>&nbsp;&nbsp;&nbsp; 1. Set 'Module General Options' ->  'jQuery & OutPut Filters' -> 'Put JS to Body' to on";
# 				err += "<br>&nbsp;&nbsp;&nbsp; 2. Find the double jQuery.js inclusion and remove it";
# 				err += "</div>";
# 			err += "</div>";
# 				jQuery(sliderID).show().html(err);
# 			}
# 		}
# 		</script>
# <link href="//covid19.lacounty.gov/wp-content/plugins/ilc-allground/css/tr-plugin-style.css?ver=1.2.5" id="tr-background-css-css" media="all" rel="stylesheet" type="text/css">
# <script src="//covid19.lacounty.gov/wp-content/plugins/cff-extensions/cff-carousel/js/carousel.js?ver=1.1" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var wpcf7 = {"apiSettings":{"root":"https:\/\/covid19.lacounty.gov\/wp-json\/contact-form-7\/v1","namespace":"contact-form-7\/v1"},"cached":"1"};
# /* ]]> */
# </script>
# <script src="//covid19.lacounty.gov/wp-content/plugins/contact-form-7/includes/js/scripts.js?ver=5.1.6" type="text/javascript"></script>
# <script src="//covid19.lacounty.gov/wp-content/plugins/custom-facebook-feed-pro/js/cff-scripts.js?ver=3.6.1" type="text/javascript"></script>
# <script src="//covid19.lacounty.gov/wp-content/plugins/ditty-news-ticker/inc/static/js/jquery.touchSwipe.min.js?ver=2.2.9" type="text/javascript"></script>
# <script src="//covid19.lacounty.gov/wp-content/plugins/ditty-news-ticker/inc/static/js/jquery.easing.js?ver=1.4.1" type="text/javascript"></script>
# <script src="//covid19.lacounty.gov/wp-content/plugins/ditty-news-ticker/inc/static/js/imagesloaded.pkgd.min.js?ver=4.1.0" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var mtphr_dnt_vars = {"is_rtl":""};
# /* ]]> */
# </script>
# <script src="//covid19.lacounty.gov/wp-content/plugins/ditty-news-ticker/inc/static/js/ditty-news-ticker.min.js?ver=1589922776" type="text/javascript"></script>
# <script src="//covid19.lacounty.gov/wp-content/plugins/inel_elementsbox_plugin/js/elementsbox.js" type="text/javascript"></script>
# <script src="//covid19.lacounty.gov/wp-content/plugins/inel_elementsbox_plugin/js/plugins/waypoints/jquery.waypoints.min.js" type="text/javascript"></script>
# <script src="//covid19.lacounty.gov/wp-content/plugins/revslider/public/assets/js/revolution.tools.min.js?ver=6.0" type="text/javascript"></script>
# <script src="//covid19.lacounty.gov/wp-content/plugins/revslider/public/assets/js/rs6.min.js?ver=6.1.3" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var blade_grve_smoothscroll_data = {"smoothscrolling":""};
# var blade_grve_owl_data = {"rtl":""};
# var blade_grve_retina_data = {"retina_support":"default"};
# var blade_grve_fullpage_data = {"fullpage":"0"};
# var blade_grve_piling_data = {"piling":"0"};
# /* ]]> */
# </script>
# <script src="//covid19.lacounty.gov/wp-content/themes/blade/js/plugins.js?ver=3.1.3" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var grve_main_data = {"siteurl":"https:\/\/covid19.lacounty.gov\/wp-content\/themes\/blade","ajaxurl":"https:\/\/covid19.lacounty.gov\/wp-admin\/admin-ajax.php","grve_wp_gallery_popup":"0","grve_back_top_top":"1","grve_string_weeks":"Weeks","grve_string_days":"Days","grve_string_hours":"Hours","grve_string_minutes":"Min","grve_string_seconds":"Sec","nonce_likes":"ffd1779feb"};
# /* ]]> */
# </script>
# <script src="//covid19.lacounty.gov/wp-content/themes/blade/js/main.js?ver=3.1.3" type="text/javascript"></script>
# <script type="text/javascript">
# function grveReadCookie(name) {var nameEQ = name + '=';var ca = document.cookie.split(';');for(var i=0;i < ca.length;i++) {var c = ca[i];while (c.charAt(0)==' ') c = c.substring(1,c.length);if (c.indexOf(nameEQ) === 0) return c.substring(nameEQ.length,c.length);}return null;}function grvePrivacyCookieConsent( cookie_name, cookie_days ) {var privacyAgreement = jQuery('.grve-privacy-agreement');privacyAgreement.on( 'click', function() {var theDate = new Date();var later = new Date( theDate.getTime() + cookie_days*24*60*60*1000 );document.cookie = cookie_name + '=true; Path=/; Expires='+later.toGMTString()+';';jQuery('#grve-privacy-bar').fadeOut(900);});if( !document.cookie.match( cookie_name ) ) {jQuery('#grve-privacy-bar').fadeIn(900);}}function grvePrivacyPopupConsent() {var privacyPopupButton = jQuery('.grve-privacy-popup-btn'),privacyRefreshButton = jQuery('.grve-privacy-refresh-btn'),privacyPopup = jQuery('#grve-privacy-popup'),privacyOverlay = jQuery('#grve-privacy-overlay');privacyPopupButton.on( 'click', function(e) {e.preventDefault();privacyPopup.fadeIn(600,function(){jQuery(window).on( 'click.grve_close_privacy_popup', function( event ) {if( !jQuery(event.target).closest('.grve-privacy-popup-wrapper').length ) {privacyPopup.fadeOut(600,function(){jQuery(window).off( 'click.grve_close_privacy_popup' );});privacyOverlay.fadeOut(600);}});});privacyOverlay.fadeIn(600);});privacyRefreshButton.on( 'click', function() {window.location.reload(true);});} grvePrivacyCookieConsent('grve-privacy-consent', '30'); grvePrivacyPopupConsent();function grvePrivacyCookieSwitch( cookie_name, initial_state ) {var theDate = new Date();var oneYearLater = new Date( theDate.getTime() + 31536000000 );var privacySwitch = jQuery('.' + cookie_name);privacySwitch.each( function() {if( document.cookie.match( cookie_name ) ) {if ( 'false' == grveReadCookie(cookie_name) ) {this.checked = false;} else {this.checked = true;}} else {if( !initial_state ) {this.checked = false;}}});privacySwitch.on( 'click', function() {if( this.checked ) {document.cookie = cookie_name + '=true; Path=/; Expires='+oneYearLater.toGMTString()+';';privacySwitch.each( function() {this.checked = true;});} else {document.cookie = cookie_name + '=false; Path=/; Expires='+oneYearLater.toGMTString()+';';privacySwitch.each( function() {this.checked = false;});}});} grvePrivacyCookieSwitch('grve-privacy-content-gtracking', '1' ); grvePrivacyCookieSwitch('grve-privacy-content-gfonts', '1' ); grvePrivacyCookieSwitch('grve-privacy-content-gmaps', '1' ); grvePrivacyCookieSwitch('grve-privacy-content-video-embeds', '1' );
# </script>
# <script src="//covid19.lacounty.gov/wp-content/plugins/vc-elegant-tabs/js/eTabs.js?ver=5.3.2" type="text/javascript"></script>
# <script src="//covid19.lacounty.gov/wp-includes/js/wp-embed.min.js?ver=5.3.2" type="text/javascript"></script>
# <script src="//covid19.lacounty.gov/wp-content/plugins/js_composer/assets/js/dist/js_composer_front.min.js?ver=6.0.5" type="text/javascript"></script>
# <script src="//covid19.lacounty.gov/wp-content/plugins/ilc-allground/js/backstretch.js?ver=1.2.5" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var allgroundjs = {"images":["https:\/\/covid19.lacounty.gov\/wp-content\/uploads\/2017\/03\/Main_Bkg_1-1024x683.jpg"],"links":[""],"captions":[""],"targets":[""],"mode":"random_single","duration":"5000","fade":"250","fade_scroll":"5","fallback_color":"000000","navigation":"","isMobile":"false","isTablet":"false","isPhoneNotTablet":"false","bgtype":"images","agid":"agid11441"};
# /* ]]> */
# </script>
# <script src="//covid19.lacounty.gov/wp-content/plugins/ilc-allground/js/tr-plugin-script.js?ver=1.2.5" type="text/javascript"></script>
# <script type="text/javascript">
# 					setREVStartSize({c: 'rev_slider_47_1',rl:[1240,1024,778,480],el:[460,461,461,461],gw:[790,715,715,715],gh:[461.76,461,461,461],layout:'fullwidth',mh:"0"});
# 					var	revapi47,
# 						tpj;
# 					jQuery(function() {
# 						tpj = jQuery;
# 						if(tpj("#rev_slider_47_1").revolution == undefined){
# 							revslider_showDoubleJqueryError("#rev_slider_47_1");
# 						}else{
# 							revapi47 = tpj("#rev_slider_47_1").show().revolution({
# 								sliderType:"carousel",
# 								jsFileLocation:"//covid19.lacounty.gov/wp-content/plugins/revslider/public/assets/js/",
# 								visibilityLevels:"1240,1024,778,480",
# 								gridwidth:"790,715,715,715",
# 								gridheight:"461.76,461,461,461",
# 								minHeight:"",
# 								spinner:"spinner0",
# 								forceOverflow:true,
# 								editorheight:"460,461,461,461",
# 								responsiveLevels:"1240,1024,778,480",
# 								carousel: {
# 									infinity:true
# 								},
# 								navigation: {
# 									onHoverStop:false
# 								},
# 								fallbacks: {
# 									allowHTML5AutoPlayOnAndroid:true
# 								},
# 							});
# 						}
#
# 					});
# 				</script>
# <script type="text/javascript">
# 					setREVStartSize({c: 'rev_slider_97_2',rl:[1240,1024,778,480],el:[500,461,461,461],gw:[715,715,715,715],gh:[500,461,461,461],layout:'fullwidth',mh:"0"});
# 					var	revapi97,
# 						tpj;
# 					jQuery(function() {
# 						tpj = jQuery;
# 						if(tpj("#rev_slider_97_2").revolution == undefined){
# 							revslider_showDoubleJqueryError("#rev_slider_97_2");
# 						}else{
# 							revapi97 = tpj("#rev_slider_97_2").show().revolution({
# 								jsFileLocation:"//covid19.lacounty.gov/wp-content/plugins/revslider/public/assets/js/",
# 								visibilityLevels:"1240,1024,778,480",
# 								gridwidth:"715,715,715,715",
# 								gridheight:"500,461,461,461",
# 								minHeight:"",
# 								lazyType:"single",
# 								editorheight:"500,461,461,461",
# 								responsiveLevels:"1240,1024,778,480",
# 								disableProgressBar:"on",
# 								navigation: {
# 									mouseScrollNavigation:false,
# 									onHoverStop:false,
# 									touch: {
# 										touchenabled:true
# 									}
# 								},
# 								parallax: {
# 									levels:[5,10,15,20,25,30,35,40,45,46,47,48,49,50,51,55],
# 									type:"scroll",
# 									origo:"slidercenter"
# 								},
# 								fallbacks: {
# 									allowHTML5AutoPlayOnAndroid:true
# 								},
# 							});
# 						}
#
# 					});
# 				</script>
# <script type="text/javascript">
# 					setREVStartSize({c: 'rev_slider_100_3',rl:[1240,1024,778,480],el:[500,461,461,461],gw:[715,715,715,715],gh:[500,461,461,461],layout:'fullwidth',mh:"0"});
# 					var	revapi100,
# 						tpj;
# 					jQuery(function() {
# 						tpj = jQuery;
# 						if(tpj("#rev_slider_100_3").revolution == undefined){
# 							revslider_showDoubleJqueryError("#rev_slider_100_3");
# 						}else{
# 							revapi100 = tpj("#rev_slider_100_3").show().revolution({
# 								jsFileLocation:"//covid19.lacounty.gov/wp-content/plugins/revslider/public/assets/js/",
# 								visibilityLevels:"1240,1024,778,480",
# 								gridwidth:"715,715,715,715",
# 								gridheight:"500,461,461,461",
# 								minHeight:"",
# 								lazyType:"single",
# 								editorheight:"500,461,461,461",
# 								responsiveLevels:"1240,1024,778,480",
# 								disableProgressBar:"on",
# 								navigation: {
# 									mouseScrollNavigation:false,
# 									onHoverStop:false,
# 									touch: {
# 										touchenabled:true
# 									}
# 								},
# 								parallax: {
# 									levels:[5,10,15,20,25,30,35,40,45,46,47,48,49,50,51,55],
# 									type:"scroll",
# 									origo:"slidercenter"
# 								},
# 								fallbacks: {
# 									allowHTML5AutoPlayOnAndroid:true
# 								},
# 							});
# 						}
#
# 					});
# 				</script>
# <script>
# 			jQuery( document ).ready( function($) {
# 							$( '#mtphr-dnt-19999' ).ditty_news_ticker({
# 					id : '19999',
# 					type : 'scroll',
# 					scroll_direction : 'left',
# 					scroll_speed : 10,
# 					scroll_pause : 0,
# 					scroll_spacing : 40,
# 					scroll_init : 0,
# 					rotate_type : 'fade',
# 					auto_rotate : 1,
# 					rotate_delay : 7,
# 					rotate_pause : 0,
# 					rotate_speed : 10,
# 					rotate_ease : 'easeInOutQuint',
# 					nav_reverse : 0,
# 					disable_touchswipe : 0,
# 					offset : 20,
# 					after_load : function( $ticker ) {
# 											},
# 					before_change : function( $ticker ) {
# 											},
# 					after_change : function( $ticker ) {
# 											}
# 				});
# 			 			});
# 		</script>
# <script async="" src="/_Incapsula_Resource?SWJIYLWA=719d34d31c8e3a6e6fffd425f7e032f3&amp;ns=1&amp;cb=762273009" type="text/javascript"></script>
# </link></body>
# </html>
# <!--
#         generated in 0.339 seconds 0 seconds ago
#         237436 bytes batcached for 60 seconds
# -->

# %%
#Total coronavirus (COVID-19) cases in Los Angeles County, CA, USA
total_cases = soup.find_all('div', attrs={'class': 'wpb_column grve-column grve-column-1-2 vc_custom_1588612589118'})
first_result = total_cases[0]
cases = first_result.find('strong').text
print(f"total COVID cases in LA County {cases}")
# Out:
# total COVID cases in LA County 55,968

# %%
#Total coronavirus (COVID-19) deaths in Los Angeles County, CA, USA
total_deaths = soup.find_all('div', attrs={'class': 'wpb_column grve-column grve-column-1-2 vc_custom_1588612594247'})
second_result = total_deaths[0]
deaths = second_result.find('strong').text
print(f"total COVID deaths in LA County {deaths}")
# Out:
# total COVID deaths in LA County 2,384

# %%
Covid_cases['LA'].extend([int(re.sub(",","",cases)),int(re.sub(",","",deaths))])
Covid_cases
# Out:
# defaultdict(list, {'LA': [55968, 2384]})

# %% [markdown]
# **Honolulu County, HI, USA**

# %%
#Provide data on total Coronavirus cases and coronavirus deaths in Honolulu County, HI, USA
html = urllib.request.urlopen('https://health.hawaii.gov/coronavirusdisease2019/').read()
soup2 = BeautifulSoup(html, 'html.parser')
body = soup2.find('body')
print(soup2)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head lang="en-US">
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <title>State of Hawai'i – Department of Health</title>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/wp-content/themes/hic_state_template_child-DOCD-COVID19/css/print.css" media="print" rel="stylesheet"/>
# <style type="text/css">
# </style>
# <script data-cfasync="false" data-pagespeed-no-defer="">//<![CDATA[
# 	var gtm4wp_datalayer_name = "dataLayer";
# 	var dataLayer = dataLayer || [];
# //]]>
# </script>
# <meta content="script­src 'self';" http-equiv="Content­-Security-­Policy"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="State of Hawai'i - Department of Health" property="og:title">
# <meta content="website" property="og:type">
# <meta content="https://health.hawaii.gov/coronavirusdisease2019" property="og:url">
# <meta content="https://health.hawaii.gov/coronavirusdisease2019/wp-content/themes/hic_state_template_parent/images/og-image.jpg" property="og:image"/>
# <meta content="Disease Outbreak Control Division" property="og:description"/>
# <link href="//maxcdn.bootstrapcdn.com" rel="dns-prefetch"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="//s.w.org" rel="dns-prefetch"/>
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/12.0.0-1\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/12.0.0-1\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/health.hawaii.gov\/coronavirusdisease2019\/wp-includes\/js\/wp-emoji-release.min.js?ver=5.4.1"}};
# 			/*! This file is auto-generated */
# 			!function(e,a,t){var r,n,o,i,p=a.createElement("canvas"),s=p.getContext&&p.getContext("2d");function c(e,t){var a=String.fromCharCode;s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,e),0,0);var r=p.toDataURL();return s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,t),0,0),r===p.toDataURL()}function l(e){if(!s||!s.fillText)return!1;switch(s.textBaseline="top",s.font="600 32px Arial",e){case"flag":return!c([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])&&(!c([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!c([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]));case"emoji":return!c([55357,56424,55356,57342,8205,55358,56605,8205,55357,56424,55356,57340],[55357,56424,55356,57342,8203,55358,56605,8203,55357,56424,55356,57340])}return!1}function d(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(i=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},o=0;o<i.length;o++)t.supports[i[o]]=l(i[o]),t.supports.everything=t.supports.everything&&t.supports[i[o]],"flag"!==i[o]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[i[o]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(r=t.source||{}).concatemoji?d(r.concatemoji):r.wpemoji&&r.twemoji&&(d(r.twemoji),d(r.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# <style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <style type="text/css">
# 	.tablepress thead th div { float:left; }
# </style><link href="https://health.hawaii.gov/coronavirusdisease2019/wp-includes/css/dashicons.min.css?ver=5.4.1" id="dashicons-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/wp-includes/js/thickbox/thickbox.css?ver=5.4.1" id="thickbox-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/wp-includes/css/dist/block-library/style.min.css?ver=5.4.1" id="wp-block-library-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/custom-facebook-feed/css/cff-style.css?ver=2.14.1" id="cff-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css?ver=5.4.1" id="sb-font-awesome-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/custom-twitter-feeds/css/ctf-styles.min.css?ver=1.5" id="ctf_styles-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/feed-them-social/feeds/css/styles.css?ver=2.8.3.1" id="fts-feeds-css" media="" rel="stylesheet" type="text/css"/>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/responsive-lightbox/assets/nivo/nivo-lightbox.min.css?ver=2.2.2" id="responsive-lightbox-nivo-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/responsive-lightbox/assets/nivo/themes/default/default.css?ver=2.2.2" id="responsive-lightbox-nivo-default-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/simple_announcer/includes/css/simple_announcer_style.css?ver=5.4.1" id="simple_announcer_style-css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/simple_category_posts/scp_style.css?ver=5.4.1" id="scp_style-css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/supertables/bootstrap.min.css?ver=5.4.1" id="bootstrap-css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/wp-translation-proxy-plugin/css/translation-proxy.css?ver=5.4.1" id="translation-proxy-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/slicknav-mobile-menu/css/slicknav.min.css?ver=1.0.10" id="slicknavcss-css" media="all" rel="stylesheet" type="text/css"/>
# <style id="slicknavcss-inline-css" type="text/css">
#
#
#         .leftsidebar_column {
#                 display: none;
#         }
#
#         .slicknav_menu {
#                 background: #4c4c4c;
#         }
#
#         .slicknav-flex{
#                display: -webkit-box;
#                display: -ms-flexbox;
#                display: flex;
#                justify-content:center;
#         }
#
#         .slicknav_btn {
#                 background-color:#222222;
#         }
#
#         a.slicknav_open {
#                 background-color:#222222;
#         }
#
#         .slicknav_nav .slicknav_arrow {
#                 float:right;
#         }
#
#         .slicknav_menu .slicknav_menutxt {
#                 color: #fff;
#                 text-shadow: none;
#                 font-size: 16px;
#                 font-weight: normal;
#         }
#
#         .slicknav_menu .slicknav_icon-bar {
#                 background-color: #fff;
#                 box-shadow: none;
#         }
#
#         .slicknav_nav li a {
#                 color: #fff;
#                 text-transform: none;
#                 font-size: 16px;
#                 padding: 5px 10px;
#         }
#
#         .slicknav_nav a:hover,
#         .slicknav_nav .slicknav_row:hover {
#                 background: #050505;
#         }
#
#         .slicknav_nav .menu-item a:hover,
#         .slicknav_nav a span:hover {
#                 color: #ffffff;
#         }
#
#         .slicknav_nav input[type='submit']{
#                 background: #222222;
#                 color: #fff;
#         }
#
#         .slicknav-logo-text a{
#                 color: #222222;
#         }
#
#
#         @media screen and (min-width: 760px) {
#                 .slicknav_menu {
#                         display: none;
#                 }
#
#                 .leftsidebar_column {
#                         display: block;
#                 }
#         }
#
# </style>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/wp-content/themes/hic_state_template_parent/admin/css/font-awesome-st.css?ver=5.4.1" id="font-awesome-st-css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/wp-content/themes/hic_state_template_parent/includes/nivo_slider/nivo-slider.css?ver=5.4.1" id="nivo_slider_style-css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/wp-content/themes/hic_state_template_parent/includes/nivo_slider/themes/default/default.css?ver=5.4.1" id="nivo_slider_theme_style-css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/wp-content/themes/hic_state_template_child-DOCD-COVID19/style.css?ver=5.4.1" id="style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/files/tablepress-combined.min.css?ver=38" id="tablepress-default-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/et-shortcodes/css/shortcodes.css?ver=3.0" id="et-shortcodes-css-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/et-shortcodes/css/shortcodes_responsive.css?ver=3.0" id="et-shortcodes-responsive-css-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/footable/css/footable.core.min.css?ver=0.3.1" id="footable-core-min-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/kadence-blocks/dist/blocks/row.style.build.css?ver=1.7.20" id="kadence-blocks-rowlayout-css" media="all" rel="stylesheet" type="text/css"/>
# <style id="kt-blocks_ed170a-9d-inline-css" type="text/css">
# #kt-layout-id_ed170a-9d > .kt-row-column-wrap {padding-top:0px;padding-bottom:0px;}
# </style>
# <style id="kt-blocks_c2ef34-c6-inline-css" type="text/css">
# .kt-row-layout-inner > .kt-row-column-wrap > .kadence-column_c2ef34-c6 > .kt-inside-inner-col {padding-top:50px;}.kt-row-layout-inner > .kt-row-column-wrap > .kadence-column_c2ef34-c6 > .kt-inside-inner-col {background-color:rgba(6, 6, 6, 1);background-image:url(https://statehawaii.dev/covid19/wp-content/uploads/sites/5/2020/03/virus_illustr-left2.jpg);background-size:contain;background-position:left top;background-attachment:scroll;background-repeat:no-repeat;}
# </style>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/kadence-blocks/dist/blocks/spacer.style.build.css?ver=1.7.20" id="kadence-blocks-spacer-css" media="all" rel="stylesheet" type="text/css"/>
# <style id="kt-blocks_2ec965-3b-inline-css" type="text/css">
# @media (min-width: 767px) and (max-width: 1024px) {.kt-block-spacer-_2ec965-3b .kt-block-spacer {height:80px !important;}}@media (max-width: 767px) {.kt-block-spacer-_2ec965-3b .kt-block-spacer {height:50px !important;}}
# </style>
# <style id="kadence-blocks-heading-inline-css" type="text/css">
# .wp-block-kadence-advancedheading mark{color:#f76a0c;background:transparent;border-style:solid;border-width:0}
# </style>
# <style id="kt-blocks_ae4285-07-inline-css" type="text/css">
# #kt-adv-heading_ae4285-07, #kt-adv-heading_ae4285-07 .wp-block-kadence-advancedheading {font-size:6em;line-height:1em;}@media (min-width: 767px) and (max-width: 1024px) {#kt-adv-heading_ae4285-07, #kt-adv-heading_ae4285-07 .wp-block-kadence-advancedheading {font-size:5em;}}@media (max-width: 767px) {#kt-adv-heading_ae4285-07, #kt-adv-heading_ae4285-07 .wp-block-kadence-advancedheading {font-size:5.5em;}}
# </style>
# <style id="kt-blocks_2c9b50-d7-inline-css" type="text/css">
# @media (min-width: 767px) and (max-width: 1024px) {.kt-block-spacer-_2c9b50-d7 .kt-block-spacer {height:80px !important;}}@media (max-width: 767px) {.kt-block-spacer-_2c9b50-d7 .kt-block-spacer {height:50px !important;}}
# </style>
# <style id="kt-blocks_76c952-a3-inline-css" type="text/css">
# #kt-layout-id_76c952-a3 {background-image:url(http://health.hawaii.gov/coronavirusdisease2019/wp-content/blogs.dir/116/files/2020/03/blue_pattern.jpg);background-size:cover;background-position:center center;background-attachment:scroll;background-repeat:no-repeat;}#kt-layout-id_76c952-a3 > .kt-row-column-wrap {padding-top:0px;padding-bottom:0px;padding-left:0px;padding-right:0px;}@media (min-width: 768px) and (max-width: 1024px) {#kt-layout-id_76c952-a3 {background-image:url(http://health.hawaii.gov/coronavirusdisease2019/wp-content/blogs.dir/116/files/2020/03/blue_pattern-vertical.jpg);background-size:cover;background-position:center center;background-attachment:scroll;background-repeat:no-repeat;}}@media (max-width: 767px) {#kt-layout-id_76c952-a3 {background-image:url(http://health.hawaii.gov/coronavirusdisease2019/wp-content/blogs.dir/116/files/2020/03/blue_pattern-vertical.jpg);background-size:cover;background-position:center center;background-attachment:scroll;background-repeat:no-repeat;}}
# </style>
# <style id="kt-blocks_244c78-4f-inline-css" type="text/css">
# .kt-row-layout-inner > .kt-row-column-wrap > .kadence-column_244c78-4f > .kt-inside-inner-col {border-color:rgba(161, 181, 202, 1);border-width:0px 1px 0px 0px ;}
# </style>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/kadence-blocks/dist/blocks/infobox.style.build.css?ver=1.7.20" id="kadence-blocks-infobox-css" media="all" rel="stylesheet" type="text/css"/>
# <style id="kt-blocks_c5def8-f6-inline-css" type="text/css">
# #kt-info-box_c5def8-f6 .kt-blocks-info-box-link-wrap {background:rgba(255, 255, 255, 0);padding:20px 20px 20px 20px;border-width:0px 0px 0px 0px;}#kt-info-box_c5def8-f6 .kt-blocks-info-box-link-wrap:hover {border-color:rgba(255, 255, 255, 0);background:rgba(0, 108, 45, 0.7);}#kt-info-box_c5def8-f6 .kt-blocks-info-box-media {color:#444444;border-width:0px 0px 0px 0px;padding:10px 10px 10px 10px;}#kt-info-box_c5def8-f6 .kt-blocks-info-box-media-container {margin:8px 0px 11px 0px;}#kt-info-box_c5def8-f6 .kt-blocks-info-box-link-wrap:hover .kt-blocks-info-box-media {color:#444444;}#kt-info-box_c5def8-f6 .kt-blocks-info-box-title {color:#ffffff;padding:0px 0px 0px 0px;margin:5px 0px 10px 0px;}
# </style>
# <style id="kt-blocks_00c1fe-65-inline-css" type="text/css">
# .kt-row-layout-inner > .kt-row-column-wrap > .kadence-column_00c1fe-65 > .kt-inside-inner-col {border-color:rgba(161, 181, 202, 1);border-width:0px 1px 0px 0px ;}
# </style>
# <style id="kt-blocks_7522bd-ad-inline-css" type="text/css">
# #kt-info-box_7522bd-ad .kt-blocks-info-box-link-wrap {background:rgba(255, 255, 255, 0);padding:20px 20px 20px 20px;border-width:0px 0px 0px 0px;}#kt-info-box_7522bd-ad .kt-blocks-info-box-link-wrap:hover {border-color:rgba(255, 255, 255, 0);background:rgba(0, 108, 45, 0.7);}#kt-info-box_7522bd-ad .kt-blocks-info-box-media {color:#444444;border-width:0px 0px 0px 0px;padding:10px 10px 10px 10px;}#kt-info-box_7522bd-ad .kt-blocks-info-box-media-container {margin:0px 15px 0px 15px;}#kt-info-box_7522bd-ad .kt-blocks-info-box-link-wrap:hover .kt-blocks-info-box-media {color:#444444;}#kt-info-box_7522bd-ad .kt-blocks-info-box-title {color:#ffffff;padding:0px 0px 0px 0px;margin:5px 0px 10px 0px;}
# </style>
# <style id="kt-blocks_2e2b3f-2b-inline-css" type="text/css">
# .kt-row-layout-inner > .kt-row-column-wrap > .kadence-column_2e2b3f-2b > .kt-inside-inner-col {border-color:rgba(161, 181, 202, 1);border-width:0px 1px 0px 0px ;}
# </style>
# <style id="kt-blocks_f0acad-e0-inline-css" type="text/css">
# #kt-info-box_f0acad-e0 .kt-blocks-info-box-link-wrap {background:rgba(255, 255, 255, 0);padding:20px 20px 20px 20px;border-width:0px 0px 0px 0px;}#kt-info-box_f0acad-e0 .kt-blocks-info-box-link-wrap:hover {border-color:rgba(255, 255, 255, 0);background:rgba(0, 108, 45, 0.7);}#kt-info-box_f0acad-e0 .kt-blocks-info-box-media {color:#444444;border-width:0px 0px 0px 0px;padding:10px 10px 10px 10px;}#kt-info-box_f0acad-e0 .kt-blocks-info-box-media-container {margin:16px 0px 7px 0px;}#kt-info-box_f0acad-e0 .kt-blocks-info-box-link-wrap:hover .kt-blocks-info-box-media {color:#444444;}#kt-info-box_f0acad-e0 .kt-blocks-info-box-title {color:#ffffff;padding:0px 0px 0px 0px;margin:5px 0px 10px 0px;}
# </style>
# <style id="kt-blocks_fd979e-c0-inline-css" type="text/css">
# .kt-row-layout-inner > .kt-row-column-wrap > .kadence-column_fd979e-c0 > .kt-inside-inner-col {padding-top:40px;padding-left:20px;}.kt-row-layout-inner > .kt-row-column-wrap > .kadence-column_fd979e-c0 {text-align:left;}@media (min-width: 768px) and (max-width: 1024px) {.kt-row-layout-inner > .kt-row-column-wrap > .kadence-column_fd979e-c0 {text-align:left;}}@media (max-width: 767px) {.kt-row-layout-inner > .kt-row-column-wrap > .kadence-column_fd979e-c0 {text-align:left;}}@media (min-width: 768px) and (max-width: 1024px) {.kt-row-layout-inner > .kt-row-column-wrap > .kadence-column_fd979e-c0 > .kt-inside-inner-col {padding-top:30px;padding-bottom:20px;padding-left:40px;padding-right:20px;}}@media (max-width: 767px) {.kt-row-layout-inner > .kt-row-column-wrap > .kadence-column_fd979e-c0 > .kt-inside-inner-col {padding-top:25px;padding-bottom:20px;padding-left:40px;padding-right:20px;}}
# </style>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/kadence-blocks/dist/blocks/btn.style.build.css?ver=1.7.20" id="kadence-blocks-btn-css" media="all" rel="stylesheet" type="text/css"/>
# <style id="kt-blocks_e1a78d-8c-inline-css" type="text/css">
# .kt-btns_e1a78d-8c .kt-btn-wrap-0 {margin-right:5px;}.kt-btns_e1a78d-8c .kt-btn-wrap-0 .kt-button {padding-left:8px;padding-right:8px;padding-top:1px;padding-bottom:1px;color:#000000;font-size:16px;background:rgba(250, 192, 96, 1);border-color:rgba(85, 85, 85, 1);}.kt-btns_e1a78d-8c .kt-btn-wrap-0 .kt-button:hover, .kt-btns_e1a78d-8c .kt-btn-wrap-0 .kt-button:focus {color:#fffcfc;border-color:rgba(68, 68, 68, 1);}.kt-btns_e1a78d-8c .kt-btn-wrap-0 .kt-button::before {display:none;}.kt-btns_e1a78d-8c .kt-btn-wrap-0 .kt-button:hover, .kt-btns_e1a78d-8c .kt-btn-wrap-0 .kt-button:focus {background:rgba(228, 56, 38, 1);}
# </style>
# <style id="kt-blocks_35698b-b1-inline-css" type="text/css">
# .kt-btns_35698b-b1 .kt-btn-wrap-0 {margin-right:5px;}.kt-btns_35698b-b1 .kt-btn-wrap-0 .kt-button {padding-left:0px;padding-right:0px;padding-top:0px;padding-bottom:0px;color:#ffffff;font-size:17px;border-color:rgba(85, 85, 85, 1);}.kt-btns_35698b-b1 .kt-btn-wrap-0 .kt-button:hover, .kt-btns_35698b-b1 .kt-btn-wrap-0 .kt-button:focus {color:#fac060;border-color:rgba(68, 68, 68, 1);}.kt-btns_35698b-b1 .kt-btn-wrap-0 .kt-button::before {display:none;}.kt-btns_35698b-b1 .kt-btn-wrap-0 .kt-button:hover, .kt-btns_35698b-b1 .kt-btn-wrap-0 .kt-button:focus {background:rgba(68, 68, 68, 0);}.kt-btns_35698b-b1 .kt-btn-wrap-1 {margin-right:1px;}.kt-btns_35698b-b1 .kt-btn-wrap-1 .kt-button {padding-left:0px;padding-right:0px;padding-top:0px;padding-bottom:0px;color:#ffffff;font-size:17px;border-color:rgba(85, 85, 85, 1);}.kt-btns_35698b-b1 .kt-btn-wrap-1 .kt-button:hover, .kt-btns_35698b-b1 .kt-btn-wrap-1 .kt-button:focus {color:#fac060;border-color:rgba(68, 68, 68, 1);}.kt-btns_35698b-b1 .kt-btn-wrap-1 .kt-button::before {display:none;}.kt-btns_35698b-b1 .kt-btn-wrap-1 .kt-button:hover, .kt-btns_35698b-b1 .kt-btn-wrap-1 .kt-button:focus {background:rgba(68, 68, 68, 0);}.kt-btns_35698b-b1 .kt-btn-wrap-2 {margin-right:5px;}.kt-btns_35698b-b1 .kt-btn-wrap-2 .kt-button {padding-left:0px;padding-right:0px;padding-top:0px;padding-bottom:0px;color:#ffffff;font-size:17px;border-color:rgba(85, 85, 85, 1);}.kt-btns_35698b-b1 .kt-btn-wrap-2 .kt-button:hover, .kt-btns_35698b-b1 .kt-btn-wrap-2 .kt-button:focus {color:#fac060;border-color:rgba(68, 68, 68, 1);}.kt-btns_35698b-b1 .kt-btn-wrap-2 .kt-button::before {display:none;}.kt-btns_35698b-b1 .kt-btn-wrap-2 .kt-button:hover, .kt-btns_35698b-b1 .kt-btn-wrap-2 .kt-button:focus {background:rgba(68, 68, 68, 0);}.kt-btns_35698b-b1 .kt-btn-wrap-3 {margin-right:5px;}.kt-btns_35698b-b1 .kt-btn-wrap-3 .kt-button {padding-left:0px;padding-right:0px;padding-top:0px;padding-bottom:0px;color:#ffffff;font-size:17px;border-color:rgba(85, 85, 85, 1);}.kt-btns_35698b-b1 .kt-btn-wrap-3 .kt-button:hover, .kt-btns_35698b-b1 .kt-btn-wrap-3 .kt-button:focus {color:#fac060;border-color:rgba(68, 68, 68, 1);}.kt-btns_35698b-b1 .kt-btn-wrap-3 .kt-button::before {display:none;}.kt-btns_35698b-b1 .kt-btn-wrap-3 .kt-button:hover, .kt-btns_35698b-b1 .kt-btn-wrap-3 .kt-button:focus {background:rgba(68, 68, 68, 0);}
# </style>
# <style id="kt-blocks_c14631-37-inline-css" type="text/css">
# #kt-layout-id_c14631-37 > .kt-row-column-wrap {padding-top:30px;padding-bottom:30px;padding-left:30px;padding-right:30px;}
# </style>
# <style id="kt-blocks_7b58ac-f2-inline-css" type="text/css">
# .kt-row-layout-inner > .kt-row-column-wrap > .kadence-column_7b58ac-f2 > .kt-inside-inner-col {padding-right:12px;border-color:rgba(0, 0, 0, 1);border-width:0px 1px 0px 0px ;}
# </style>
# <style id="kt-blocks_f5d91a-fb-inline-css" type="text/css">
# .kt-btns_f5d91a-fb .kt-btn-wrap-0 {margin-right:5px;}.kt-btns_f5d91a-fb .kt-btn-wrap-0 .kt-button {color:#ffffff;font-size:15px;background:rgba(228, 56, 38, 1);border-color:rgba(85, 85, 85, 1);}.kt-btns_f5d91a-fb .kt-btn-wrap-0 .kt-button:hover, .kt-btns_f5d91a-fb .kt-btn-wrap-0 .kt-button:focus {color:#ffffff;border-color:rgba(68, 68, 68, 1);}.kt-btns_f5d91a-fb .kt-btn-wrap-0 .kt-button::before {display:none;}.kt-btns_f5d91a-fb .kt-btn-wrap-0 .kt-button:hover, .kt-btns_f5d91a-fb .kt-btn-wrap-0 .kt-button:focus {background:rgba(68, 68, 68, 1);}
# </style>
# <style id="kt-blocks_156c8f-8d-inline-css" type="text/css">
# .kt-row-layout-inner > .kt-row-column-wrap > .kadence-column_156c8f-8d > .kt-inside-inner-col {padding-left:12px;padding-right:12px;border-color:rgba(0, 0, 0, 1);border-width:0px 1px 0px 0px ;}
# </style>
# <style id="kt-blocks_57d424-22-inline-css" type="text/css">
# .kt-btns_57d424-22 .kt-btn-wrap-0 {margin-right:5px;}.kt-btns_57d424-22 .kt-btn-wrap-0 .kt-button {color:#ffffff;font-size:15px;background:rgba(228, 56, 38, 1);border-color:rgba(85, 85, 85, 1);}.kt-btns_57d424-22 .kt-btn-wrap-0 .kt-button:hover, .kt-btns_57d424-22 .kt-btn-wrap-0 .kt-button:focus {color:#ffffff;border-color:rgba(68, 68, 68, 1);}.kt-btns_57d424-22 .kt-btn-wrap-0 .kt-button::before {display:none;}.kt-btns_57d424-22 .kt-btn-wrap-0 .kt-button:hover, .kt-btns_57d424-22 .kt-btn-wrap-0 .kt-button:focus {background:rgba(68, 68, 68, 1);}
# </style>
# <style id="kt-blocks_cfdebd-65-inline-css" type="text/css">
# .kt-row-layout-inner > .kt-row-column-wrap > .kadence-column_cfdebd-65 > .kt-inside-inner-col {padding-left:12px;}
# </style>
# <style id="kt-blocks_87eb5d-88-inline-css" type="text/css">
# .kt-btns_87eb5d-88 .kt-btn-wrap-0 {margin-right:5px;}.kt-btns_87eb5d-88 .kt-btn-wrap-0 .kt-button {color:#ffffff;font-size:15px;background:rgba(228, 56, 38, 1);border-color:rgba(85, 85, 85, 1);}.kt-btns_87eb5d-88 .kt-btn-wrap-0 .kt-button:hover, .kt-btns_87eb5d-88 .kt-btn-wrap-0 .kt-button:focus {color:#ffffff;border-color:rgba(68, 68, 68, 1);}.kt-btns_87eb5d-88 .kt-btn-wrap-0 .kt-button::before {display:none;}.kt-btns_87eb5d-88 .kt-btn-wrap-0 .kt-button:hover, .kt-btns_87eb5d-88 .kt-btn-wrap-0 .kt-button:focus {background:rgba(68, 68, 68, 1);}
# </style>
# <link href="//fonts.googleapis.com/css?family=Open+Sans%3A300%2C400%2C400i%2C700&amp;ver=5.4.1" id="chld_thm_cfg_ext1-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/featured-page-widget/templates/featured-page-widget.css?ver=5.4.1" id="featured-widget-css-css" media="all" rel="stylesheet" type="text/css"/>
# <script src="https://health.hawaii.gov/coronavirusdisease2019/wp-includes/js/jquery/jquery.js?ver=1.12.4-wp" type="text/javascript"></script>
# <script src="https://health.hawaii.gov/coronavirusdisease2019/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.4.1" type="text/javascript"></script>
# <script src="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/jquery-vertical-accordion-menu/js/jquery.hoverIntent.minified.js?ver=5.4.1" type="text/javascript"></script>
# <script src="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/jquery-vertical-accordion-menu/js/jquery.cookie.js?ver=5.4.1" type="text/javascript"></script>
# <script src="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/jquery-vertical-accordion-menu/js/jquery.dcjqaccordion.2.9.js?ver=5.4.1" type="text/javascript"></script>
# <script src="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/feed-them-social/feeds/js/powered-by.js?ver=2.8.3.1" type="text/javascript"></script>
# <script src="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/feed-them-social/feeds/js/fts-global.js?ver=2.8.3.1" type="text/javascript"></script>
# <script src="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/responsive-lightbox/assets/infinitescroll/infinite-scroll.pkgd.min.js?ver=5.4.1" type="text/javascript"></script>
# <script src="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/wp-translation-proxy-plugin/js/translation-proxy.js?ver=5.4.1" type="text/javascript"></script>
# <script src="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/slicknav-mobile-menu/js/jquery.slicknav.min.js?ver=1.0.10" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var slickNavVars = {"ng_slicknav":{"ng_slicknav_menu":".leftsidebar_column","ng_slicknav_position":"section","ng_slicknav_parent_links":false,"ng_slicknav_close_click":false,"ng_slicknav_child_links":false,"ng_slicknav_speed":200,"ng_slicknav_label":"COVID-19 MENU","ng_slicknav_fixhead":false,"ng_slicknav_hidedesktop":"block","ng_slicknav_brand":"","ng_slicknav_brand_text":"","ng_slicknav_search":false,"ng_slicknav_search_text":"search...","ng_slicksearch":"https:\/\/health.hawaii.gov\/coronavirusdisease2019\/","ng_slicknav_closedsymbol":"","ng_slicknav_openedsymbol":"","ng_slicknav_alt":"","ng_slicknav_accordion":false,"ng_slicknav_animation_library":"jquery"}};
# /* ]]> */
# </script>
# <script src="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/slicknav-mobile-menu/js/slick-init.js?ver=1.8.0" type="text/javascript"></script>
# <script src="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/duracelltomi-google-tag-manager/js/gtm4wp-form-move-tracker.js?ver=1.11.4" type="text/javascript"></script>
# <script src="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/footable/js/footable.min.js?ver=0.3.1" type="text/javascript"></script>
# <script src="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/footable/js/footable.sort.min.js?ver=0.3.1" type="text/javascript"></script>
# <script src="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/footable/js/footable.filter.min.js?ver=0.3.1" type="text/javascript"></script>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/wp-json/" rel="https://api.w.org/"/>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/" rel="canonical"/>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/" rel="shortlink"/>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fhealth.hawaii.gov%2Fcoronavirusdisease2019%2F" rel="alternate" type="application/json+oembed"/>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fhealth.hawaii.gov%2Fcoronavirusdisease2019%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
# <link href="//health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/list-category-posts-with-pagination/pagination.css" rel="stylesheet" type="text/css"/>
# <script data-cfasync="false" data-pagespeed-no-defer="">//<![CDATA[//]]>
# </script>
# <!--[if lt IE 9]>
# 		<script>
# 			document.createElement('header');
# 			document.createElement('nav');
# 			document.createElement('section');
# 			document.createElement('article');
# 			document.createElement('aside');
# 			document.createElement('footer');
# 			document.createElement('hgroup');
# 		</script>
# 	<![endif]-->
# <script type="text/javascript">/* FooTable init code */
#
# var $FOOTABLE = $FOOTABLE || {};
# (function( $FOOTABLE, $, undefined ) {
#
# 	jQuery.fn.attrAppendWithComma=function(a,b){var c;return this.each(function(){c=$(this),void 0!==c.attr(a)&&""!=c.attr(a)?c.attr(a,c.attr(a)+","+b):c.attr(a,b)})};jQuery.fn.footableAttr=function(a,b){return this.each(function(){var c=$(this);c.data("auto-columns")!==!1&&(c.find("thead th:gt("+a+")").attrAppendWithComma("data-hide","tablet"),c.find("thead th:gt("+b+")").attrAppendWithComma("data-hide","phone"))})},jQuery.fn.footableFilter=function(a){return this.each(function(){var b=$(this);b.data("filter")||b.data("filter")===!1||b.data("filter-text-only","true").before('<div class="footable-filter-container"><input placeholder="'+a+'" style="float:right" type="text" class="footable-filter" /></div>')})},jQuery.fn.footablePager=function(){return this.each(function(){var a=$(this);if(a.data("page")!==!1){var b=$('<tfoot class="hide-if-no-paging"><tr><td><div class="pagination pagination-centered"></div></td></tr></tfoot>');b.find("td").attr("colspan",a.find("thead th").length),a.find("tbody:last").after(b)}})};
#
# 	$FOOTABLE.init = function() {
# 		$(".footable, .tablepress")
# 			.footableAttr(3,1)
# 			.footableFilter("search")
# 			.footable( { breakpoints: { phone: 320, tablet: 768 } });
#
# 	};
# }( $FOOTABLE, jQuery ));
#
# jQuery(function($) {
# 	$FOOTABLE.init();
# });
# </script> <script>
# 		jQuery(document).ready(function() {
# 			jQuery('#navigation ul').superclick();
#
# 			jQuery('.page_item').has('.children').addClass('sf-with-ul');
# 			jQuery('.page_item').has('.children').append('<span class="ie7_arrow" style="display: none;"></span>');
# 			jQuery('.menu-item').has('.sub-menu').addClass('sf-with-ul');
# 			jQuery('.menu-item').has('.sub-menu').append('<span class="ie7_arrow" style="display: none;"></span>');
# 		});
# 	</script>
# <script crossorigin="anonymous" src="https://kit.fontawesome.com/922f088e41.js"></script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-121062049-3"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-121062049-3');
# </script>
# <link href="https://health.hawaii.gov/coronavirusdisease2019/wp-content/themes/hic_state_template_parent/favicon.ico" rel="shortcut icon"/>
# </meta></meta></meta></head>
# <body class="no-js">
# <div id="scheme_color_green">
# <div data-background="https://health.hawaii.gov/coronavirusdisease2019/wp-content/themes/hic_state_template_parent/admin/images/backgrounds/bg-image-1.jpg" id="backgroundCover">
# </div>
# <script>
# 			if(jQuery('body').outerWidth() > 767) {
# 				var background = jQuery('#backgroundCover').attr('data-background');
# 				jQuery('#backgroundCover').css({'background':'url(' + background + ')','background-repeat':'no-repeat', 'background-attachment':'fixed', 'background-size':'cover'});
# 			}
# 		</script>
# <nav aria-label="Skip navigation" class="skip">
# <ul>
# <li><a href="#main">Skip to Content</a></li>
# <li><a href="#navigation">Skip to Navigation</a></li>
# <li><a href="#footer">Skip to Footer</a></li>
# </ul>
# </nav>
# <div id="wrap">
# <div aria-label="Statewide banner" class="statewide-header" id="sliver" role="region">
# <div class="statewide-banner">
# <div class="statewide-banner-left" id="hawaii-home">
# <a href="https://portal.ehawaii.gov/" title="Link to Hawaii.gov">Hawaii.gov</a>
# </div>
# <div class="statewide-banner-left" id="font-resize">
# Text size:
# <ul>
# <li class="fontResizer" style="text-align: center;">
# <a class="fontSizeMinus" title="Decrease font size">Smaller</a> | <a class="fontReset" title="Reset font size">Reset</a> | <a class="fontSizePlus" title="Increase font size">Larger</a> <input id="fontResizer_value" type="hidden" value="body"/>
# <input id="fontResizer_ownid" type="hidden" value=""/>
# <input id="fontResizer_ownelement" type="hidden" value=""/>
# <input id="fontResizer_resizeSteps" type="hidden" value="1.6"/><input id="fontResizer_cookieTime" type="hidden" value="31"/>
# </li>
# </ul>
# </div>
# <div class="notmobile statewide-banner-right">
# <a href="https://stayconnected.hawaii.gov/" title="Link to Stay Connected">Stay Connected</a>
# </div>
# </div>
# </div>
# <div id="inner-wrap">
# <div class="group" id="page">
# <header>
# <div class="group" id="header">
# <div class="inner-header group">
# <div id="nav_toggle">
# <i aria-hidden="true" class="icon-list"></i>
# </div>
# <div class="nine-col logo">
# <a href="https://health.hawaii.gov/coronavirusdisease2019">
# <img alt="State of Hawai'i – Department of Health logo" height="0" src="https://health.hawaii.gov/coronavirusdisease2019/wp-content/themes/hic_state_template_parent/admin/images/seal/logo.png" width="0"/>
# </a>
# <div class="title_tagline">
# <span class="tagline">Disease Outbreak Control Division</span>
# <h1 class="title"><a href="https://health.hawaii.gov/coronavirusdisease2019">State of Hawai'i – Department of Health</a></h1>
# </div>
# </div>
# <div class="three-col last-col" id="header_search">
# <form action="https://health.hawaii.gov/coronavirusdisease2019">
# <label class="sr-only" for="s">Search this site</label>
# <input id="s" name="s" placeholder="Search" type="text" value=""/>
# <input name="type" type="hidden" value="usa"/> <button class="custom_color_bg_hover" type="submit">
# <i aria-hidden="true" class="icon-search"></i>
# <span class="search-button-text">Search</span>
# </button>
# </form>
# </div>
# <div id="search_toggle">
# <i aria-hidden="true" class="icon-search"></i>
# </div>
# <div class="three-col last-col" id="additional-info">
# <div id="et-social-icons">
# </div>
# </div>
# </div>
# <div aria-label="Main navigation" id="navigation" role="navigation" tabindex="-1">
# <div class="grid-container scheme_bg_green twelve-col">
# <div class="menu-docd-container"><ul class="grid-100 mobile-grid-100" id="menu-docd"><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15786" id="menu-item-15786"><a href="https://health.hawaii.gov/docd/">Home</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-15783" id="menu-item-15783"><a href="#">Vaccines &amp; Immunizations</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-15784" id="menu-item-15784"><a href="https://health.hawaii.gov/docd/vaccines-immunizations/recommendations-by-age/">Recommendations by Age</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15787" id="menu-item-15787"><a href="https://health.hawaii.gov/docd/vaccines-immunizations/recommendations-by-age/infants-toddlers/">Infants &amp; Toddlers</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15788" id="menu-item-15788"><a href="https://health.hawaii.gov/docd/vaccines-immunizations/recommendations-by-age/preteens-adolescents/">Preteens &amp; Adolescents</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15789" id="menu-item-15789"><a href="https://health.hawaii.gov/docd/vaccines-immunizations/recommendations-by-age/adults/">Adults</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15790" id="menu-item-15790"><a href="https://health.hawaii.gov/docd/vaccines-immunizations/school-health-requirements/">School Health Requirements</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15791" id="menu-item-15791"><a href="https://health.hawaii.gov/docd/disease-types/vaccine-preventable/">Vaccine-Preventable</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15792" id="menu-item-15792"><a href="https://health.hawaii.gov/docd/disease_listing/influenza-flu/">Seasonal Flu</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15793" id="menu-item-15793"><a href="https://health.hawaii.gov/docd/resources/travelers-health/">Traveler’s Health</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15794" id="menu-item-15794"><a href="https://health.hawaii.gov/docd/vaccines-immunizations/programs/">Hawaii Immunization Registry (HIR)</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15795" id="menu-item-15795"><a href="https://health.hawaii.gov/docd/vaccines-immunizations/stop-flu-at-school-sfas/">Stop Flu at School (SFAS)</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15796" id="menu-item-15796"><a href="https://health.hawaii.gov/docd/vaccines-immunizations/vaccines-for-children-vfc-program/">Vaccines for Children (VFC) Program</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15797" id="menu-item-15797"><a href="https://health.hawaii.gov/docd/vaccines-immunizations/vaccine-locators/">Vaccine Locator</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-15808" id="menu-item-15808"><a href="https://health.hawaii.gov/docd/diseases-a-z/">Diseases</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15807" id="menu-item-15807"><a href="https://health.hawaii.gov/docd/diseases-a-z/">Diseases A-Z</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-15809" id="menu-item-15809"><a href="https://health.hawaii.gov/docd/disease-types/">Disease Types</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15810" id="menu-item-15810"><a href="https://health.hawaii.gov/docd/disease-types/animal-transmitted/">Animal-Transmitted</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15811" id="menu-item-15811"><a href="https://health.hawaii.gov/docd/disease-types/bioterrorism-related/">Bioterrorism-Related</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15812" id="menu-item-15812"><a href="https://health.hawaii.gov/docd/disease-types/bloodborne/">Bloodborne</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15813" id="menu-item-15813"><a href="https://health.hawaii.gov/docd/disease-types/childhood/">Childhood</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15814" id="menu-item-15814"><a href="https://health.hawaii.gov/docd/disease-types/community-infections/">Community acquired Infections</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15815" id="menu-item-15815"><a href="https://health.hawaii.gov/docd/disease-types/environmental/">Environmental</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15816" id="menu-item-15816"><a href="https://health.hawaii.gov/docd/disease-types/foodborne/">Foodborne</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15817" id="menu-item-15817"><a href="https://health.hawaii.gov/docd/disease-types/healthcare-hospital-transmitted/">Healthcare &amp; Hospital-Transmitted</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15819" id="menu-item-15819"><a href="https://health.hawaii.gov/docd/disease-types/influenza/">Influenza</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15818" id="menu-item-15818"><a href="https://health.hawaii.gov/docd/disease-types/mosquito-transmitted/">Mosquito-Transmitted</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15820" id="menu-item-15820"><a href="https://health.hawaii.gov/docd/disease-types/pest-transmitted/">Pest-Transmitted</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15821" id="menu-item-15821"><a href="https://health.hawaii.gov/docd/disease-types/recreation-related/">Recreation-Related</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15822" id="menu-item-15822"><a href="https://health.hawaii.gov/docd/disease-types/respiratory-viruses/">Respiratory Viruses</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15823" id="menu-item-15823"><a href="https://health.hawaii.gov/docd/disease-types/sexually-transmitted/">Sexually Transmitted</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15824" id="menu-item-15824"><a href="https://health.hawaii.gov/docd/disease-types/travel-related/">Travel-Related</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15825" id="menu-item-15825"><a href="https://health.hawaii.gov/docd/disease-types/vaccine-preventable/">Vaccine-Preventable</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15826" id="menu-item-15826"><a href="https://health.hawaii.gov/docd/disease-types/waterborne/">Waterborne</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-15827" id="menu-item-15827"><a href="https://health.hawaii.gov/docd/prevention/">Prevention</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15828" id="menu-item-15828"><a href="https://health.hawaii.gov/docd/prevention/vaccines/">Vaccines</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15829" id="menu-item-15829"><a href="https://health.hawaii.gov/docd/prevention/handwashing-and-hand-hygiene/">Handwashing and Hand Hygiene</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15830" id="menu-item-15830"><a href="https://health.hawaii.gov/docd/prevention/using-antibiotics-wisely/">Using Antibiotics Wisely</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15831" id="menu-item-15831"><a href="https://health.hawaii.gov/docd/prevention/mosquito-bite-prevention/">Mosquito Bite Prevention</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15832" id="menu-item-15832"><a href="https://health.hawaii.gov/docd/resources/travelers-health/">Traveler’s Health</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-15833" id="menu-item-15833"><a href="https://health.hawaii.gov/docd/prevention/natural-disasters/">Natural Disasters and Pandemics</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15834" id="menu-item-15834"><a href="https://health.hawaii.gov/docd/prevention/natural-disasters/natural-disasters-and-disease-threats/">Natural Disasters</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15835" id="menu-item-15835"><a href="https://health.hawaii.gov/docd/prevention/natural-disasters/pandemics/">Pandemics</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15837" id="menu-item-15837"><a href="https://health.hawaii.gov/docd/prevention/bioterrorism/">Bioterrorism, Chemical, Radiological, and Nuclear Emergencies</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-15838" id="menu-item-15838"><a href="https://health.hawaii.gov/docd/reporting-an-illness/restaurant-related/">Reporting an Illness</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15839" id="menu-item-15839"><a href="https://health.hawaii.gov/docd/reporting-an-illness/restaurant-related/">Restaurant-Related</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15840" id="menu-item-15840"><a href="https://health.hawaii.gov/docd/reporting-an-illness/individual/">Individual</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15841" id="menu-item-15841"><a href="https://health.hawaii.gov/docd/reporting-an-illness/school-related/">School-Related</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15842" id="menu-item-15842"><a href="https://health.hawaii.gov/docd/reporting-an-illness/long-term-care-related/">Long-Term Care-Related</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15843" id="menu-item-15843"><a href="https://health.hawaii.gov/docd/for-healthcare-providers/reporting-an-illness-for-healthcare-providers/">For Healthcare Providers</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-15844" id="menu-item-15844"><a href="https://health.hawaii.gov/docd/resources/travelers-health/">Resources</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15845" id="menu-item-15845"><a href="https://health.hawaii.gov/docd/resources/travelers-health/">Traveler’s Health</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15846" id="menu-item-15846"><a href="https://health.hawaii.gov/docd/vaccines-immunizations/vaccine-locators/">Vaccine Locator</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15847" id="menu-item-15847"><a href="https://health.hawaii.gov/docd/resources/disaster-preparedness/">Disaster Preparedness</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-15848" id="menu-item-15848"><a href="https://health.hawaii.gov/docd/resources/reports/">Reports</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15849" id="menu-item-15849"><a href="https://health.hawaii.gov/docd/resources/reports/school-assessment-reports/">School Assessment Reports</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15850" id="menu-item-15850"><a href="https://health.hawaii.gov/docd/resources/reports/influenza-reports/">Influenza Reports</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15851" id="menu-item-15851"><a href="https://health.hawaii.gov/docd/resources/reports/healthcare-associated-infections-hais-reports/">Healthcare Associated Infections (HAIs) Reports</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15852" id="menu-item-15852"><a href="https://health.hawaii.gov/docd/resources/reports/summary-of-reported-cases-of-notifiable-diseases/">Summary of Reported Cases of Notifiable Diseases</a></li>
# ...
# </div></div>
# <div class="wp-block-kadence-column inner-column-3 kadence-column_2e2b3f-2b"><div class="kt-inside-inner-col">
# <div class="wp-block-kadence-infobox" id="kt-info-box_f0acad-e0"><a class="kt-blocks-info-box-link-wrap kt-blocks-info-box-media-align-top kt-info-halign-center" href="/coronavirusdisease2019/travel/travel-advisories/"><div class="kt-blocks-info-box-media-container"><div class="kt-blocks-info-box-media kt-info-media-animate-none"><div class="kadence-info-box-image-inner-intrisic-container" style="max-width:78px"><div class="kadence-info-box-image-intrisic kt-info-animate-none" style="padding-bottom:100.78125%;height:0;width:128px;max-width:100%"><div class="kadence-info-box-image-inner-intrisic"><img alt="" class="kt-info-box-image wp-image-15636" height="129" src="https://health.hawaii.gov/coronavirusdisease2019/wp-content/blogs.dir/116/files/2020/03/icon-plane.png" width="128"/></div></div></div></div></div><div class="kt-infobox-textcontent"><h2 class="kt-blocks-info-box-title">Travel Information</h2></div></a></div>
# </div></div>
# <div class="wp-block-kadence-column inner-column-4 kadence-column_fd979e-c0"><div class="kt-inside-inner-col">
# <div class="wp-block-kadence-advancedbtn kt-btn-align-left kt-btn-tablet-align-inherit kt-btn-mobile-align-inherit kt-btns-wrap kt-btns_e1a78d-8c"><div class="kt-btn-wrap kt-btn-wrap-0"><a class="kt-button button kt-btn-0-action kt-btn-size-custom kt-btn-style-basic kt-btn-svg-show-always kt-btn-has-text-true kt-btn-has-svg-true" href="/coronavirusdisease2019/for-clinicians/" style="border-radius:6px;border-width:0px"><span class="kt-btn-inner-text"> <strong>FOR CLINICIANS </strong> </span><div class="kt-btn-svg-icon kt-btn-svg-icon-fas_caret-right kt-btn-side-right" style="display:inline-flex;justify-content:center;align-items:center"><svg fill="currentColor" height="16" style="display:inline-block;vertical-align:middle" viewbox="0 0 192 512" width="16" xmlns="http://www.w3.org/2000/svg"><path d="M0 384.662V127.338c0-17.818 21.543-26.741 34.142-14.142l128.662 128.662c7.81 7.81 7.81 20.474 0 28.284L34.142 398.804C21.543 411.404 0 402.48 0 384.662z"></path></svg></div></a></div></div>
# <div aria-hidden="true" class="wp-block-spacer" style="height:20px"></div>
# <div class="wp-block-kadence-advancedbtn kt-btn-align-left kt-btn-tablet-align-left kt-btn-mobile-align-left kt-btns-wrap kt-btns_35698b-b1 button_array"><div class="kt-btn-wrap kt-btn-wrap-0"><a class="kt-button button kt-btn-0-action kt-btn-size-custom kt-btn-style-basic kt-btn-svg-show-always kt-btn-has-text-true kt-btn-has-svg-true front" href="/coronavirusdisease2019/for-clinicians/evaluating-puis/" style="border-width:0px"><span class="kt-btn-inner-text"> Evaluating PUI</span><div class="kt-btn-svg-icon kt-btn-svg-icon-fas_caret-right kt-btn-side-right" style="display:inline-flex;justify-content:center;align-items:center"><svg fill="currentColor" height="17" style="display:inline-block;vertical-align:middle" viewbox="0 0 192 512" width="17" xmlns="http://www.w3.org/2000/svg"><path d="M0 384.662V127.338c0-17.818 21.543-26.741 34.142-14.142l128.662 128.662c7.81 7.81 7.81 20.474 0 28.284L34.142 398.804C21.543 411.404 0 402.48 0 384.662z"></path></svg></div></a></div><div class="kt-btn-wrap kt-btn-wrap-1"><a class="kt-button button kt-btn-1-action kt-btn-size-custom kt-btn-style-basic kt-btn-svg-show-always kt-btn-has-text-true kt-btn-has-svg-true front" href="/coronavirusdisease2019/for-clinicians/infection-control/" style="border-width:0px"><span class="kt-btn-inner-text">Infection Control</span><div class="kt-btn-svg-icon kt-btn-svg-icon-fas_caret-right kt-btn-side-right" style="display:inline-flex;justify-content:center;align-items:center"><svg fill="currentColor" height="17" style="display:inline-block;vertical-align:middle" viewbox="0 0 192 512" width="17" xmlns="http://www.w3.org/2000/svg"><path d="M0 384.662V127.338c0-17.818 21.543-26.741 34.142-14.142l128.662 128.662c7.81 7.81 7.81 20.474 0 28.284L34.142 398.804C21.543 411.404 0 402.48 0 384.662z"></path></svg></div></a></div><div class="kt-btn-wrap kt-btn-wrap-2"><a class="kt-button button kt-btn-2-action kt-btn-size-custom kt-btn-style-basic kt-btn-svg-show-always kt-btn-has-text-true kt-btn-has-svg-true front" href="/coronavirusdisease2019/for-clinicians/sentinel-and-influenza-surveillance/" style="border-width:0px"><span class="kt-btn-inner-text">Sentinel &amp; Influenza Surveillance</span><div class="kt-btn-svg-icon kt-btn-svg-icon-fas_caret-right kt-btn-side-right" style="display:inline-flex;justify-content:center;align-items:center"><svg fill="currentColor" height="17" style="display:inline-block;vertical-align:middle" viewbox="0 0 192 512" width="17" xmlns="http://www.w3.org/2000/svg"><path d="M0 384.662V127.338c0-17.818 21.543-26.741 34.142-14.142l128.662 128.662c7.81 7.81 7.81 20.474 0 28.284L34.142 398.804C21.543 411.404 0 402.48 0 384.662z"></path></svg></div></a></div><div class="kt-btn-wrap kt-btn-wrap-3"><a class="kt-button button kt-btn-3-action kt-btn-size-custom kt-btn-style-basic kt-btn-svg-show-always kt-btn-has-text-true kt-btn-has-svg-true front" href="/coronavirusdisease2019/for-clinicians/resources/" style="border-width:0px"><span class="kt-btn-inner-text"> Resources for Clinicians</span><div class="kt-btn-svg-icon kt-btn-svg-icon-fas_caret-right kt-btn-side-right" style="display:inline-flex;justify-content:center;align-items:center"><svg fill="currentColor" height="17" style="display:inline-block;vertical-align:middle" viewbox="0 0 192 512" width="17" xmlns="http://www.w3.org/2000/svg"><path d="M0 384.662V127.338c0-17.818 21.543-26.741 34.142-14.142l128.662 128.662c7.81 7.81 7.81 20.474 0 28.284L34.142 398.804C21.543 411.404 0 402.48 0 384.662z"></path></svg></div></a></div></div>
# </div></div>
# </div></div></div>
# <div class="wp-block-kadence-rowlayout alignnone front_highlights_panel"><div class="kt-row-layout-inner kt-layout-id_c14631-37" id="kt-layout-id_c14631-37"><div class="kt-row-column-wrap kt-has-3-columns kt-gutter-none kt-v-gutter-wide kt-row-valign-top kt-row-layout-equal kt-tab-layout-inherit kt-m-colapse-left-to-right kt-mobile-layout-row kt-inner-column-height-full">
# <div class="wp-block-kadence-column inner-column-1 kadence-column_7b58ac-f2"><div class="kt-inside-inner-col">
# <div class="wp-block-group"><div class="wp-block-group__inner-container">
# <figure class="wp-block-image size-large"><img alt="" class="wp-image-16061" sizes="(max-width: 800px) 100vw, 800px" src="https://health.hawaii.gov/coronavirusdisease2019/wp-content/blogs.dir/116/files/2020/03/thumb-woman_coughing.jpg" srcset="https://health.hawaii.gov/coronavirusdisease2019/files/2020/03/thumb-woman_coughing.jpg 800w, https://health.hawaii.gov/coronavirusdisease2019/files/2020/03/thumb-woman_coughing-500x252.jpg 500w, https://health.hawaii.gov/coronavirusdisease2019/files/2020/03/thumb-woman_coughing-768x387.jpg 768w"/><figcaption>IF YOU BECOME SICK</figcaption></figure>
# <p>If you have symptoms or start to feel sick, stay at home and isolate yourself. Call ahead before seeing a doctor and notify them that you may have COVID-19.</p>
# <div class="wp-block-kadence-advancedbtn kt-btn-align-left kt-btn-tablet-align-inherit kt-btn-mobile-align-inherit kt-btns-wrap kt-btns_f5d91a-fb"><div class="kt-btn-wrap kt-btn-wrap-0"><a class="kt-button button kt-btn-0-action kt-btn-size-small kt-btn-style-basic kt-btn-svg-show-always kt-btn-has-text-true kt-btn-has-svg-false" href="/coronavirusdisease2019/what-you-can-do/if-you-become-sick/" style="border-radius:7px;border-width:0px"><span class="kt-btn-inner-text">LEARN MORE</span></a></div></div>
# </div></div>
# </div></div>
# <div class="wp-block-kadence-column inner-column-2 kadence-column_156c8f-8d"><div class="kt-inside-inner-col">
# <div class="wp-block-group"><div class="wp-block-group__inner-container">
# <figure class="wp-block-image size-large"><img alt="" class="wp-image-15707" sizes="(max-width: 800px) 100vw, 800px" src="https://health.hawaii.gov/coronavirusdisease2019/wp-content/blogs.dir/116/files/2020/03/thumb-hand_washing.jpg" srcset="https://health.hawaii.gov/coronavirusdisease2019/files/2020/03/thumb-hand_washing.jpg 800w, https://health.hawaii.gov/coronavirusdisease2019/files/2020/03/thumb-hand_washing-500x258.jpg 500w, https://health.hawaii.gov/coronavirusdisease2019/files/2020/03/thumb-hand_washing-768x396.jpg 768w"/><figcaption>PREVENTION</figcaption></figure>
# <p>Wash your hands often. Use soap and water for at least 20 seconds, especially after going to the bathroom; before eating; and after blowing your nose, coughing, or sneezing.</p>
# <div class="wp-block-kadence-advancedbtn kt-btn-align-left kt-btn-tablet-align-inherit kt-btn-mobile-align-inherit kt-btns-wrap kt-btns_57d424-22"><div class="kt-btn-wrap kt-btn-wrap-0"><a class="kt-button button kt-btn-0-action kt-btn-size-small kt-btn-style-basic kt-btn-svg-show-always kt-btn-has-text-true kt-btn-has-svg-false" href="/coronavirusdisease2019/what-you-can-do/how-to-prevent-the-spread-of-covid-19/" style="border-radius:7px;border-width:0px"><span class="kt-btn-inner-text">LEARN MORE</span></a></div></div>
# </div></div>
# </div></div>
# <div class="wp-block-kadence-column inner-column-3 kadence-column_cfdebd-65"><div class="kt-inside-inner-col">
# <div class="wp-block-group"><div class="wp-block-group__inner-container">
# <figure class="wp-block-image size-large"><img alt="" class="wp-image-15714" sizes="(max-width: 800px) 100vw, 800px" src="https://health.hawaii.gov/coronavirusdisease2019/wp-content/blogs.dir/116/files/2020/03/thumb-doctor.jpg" srcset="https://health.hawaii.gov/coronavirusdisease2019/files/2020/03/thumb-doctor.jpg 800w, https://health.hawaii.gov/coronavirusdisease2019/files/2020/03/thumb-doctor-500x250.jpg 500w, https://health.hawaii.gov/coronavirusdisease2019/files/2020/03/thumb-doctor-768x384.jpg 768w, https://health.hawaii.gov/coronavirusdisease2019/files/2020/03/thumb-doctor-638x319.jpg 638w"/><figcaption>FOR CLINICIANS</figcaption></figure>
# <p>Resources for clinicians: Get the latest updates on testing protocol and specific treatments for COVID-19 infection.</p>
# <div class="wp-block-kadence-advancedbtn kt-btn-align-left kt-btn-tablet-align-inherit kt-btn-mobile-align-inherit kt-btns-wrap kt-btns_87eb5d-88"><div class="kt-btn-wrap kt-btn-wrap-0"><a class="kt-button button kt-btn-0-action kt-btn-size-small kt-btn-style-basic kt-btn-svg-show-always kt-btn-has-text-true kt-btn-has-svg-false" href="/coronavirusdisease2019/for-clinicians/evaluating-puis/" style="border-radius:7px;border-width:0px"><span class="kt-btn-inner-text">LEARN MORE</span></a></div></div>
# </div></div>
# </div></div>
# </div></div></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div id="footer" role="contentinfo" tabindex="-1">
# <div id="footer-widgets">
# <div class="widget-1 widget-first footer_widget two-col" id="text-25"> <div class="textwidget"><p>Official website for the State of Hawaii Department of Health, Disease Outbreak Control Division (DOCD) coronavirus COVID-19 response. Provides information including regular updates, Hawaii daily case counts, symptoms of disease, and prevention messaging.</p>
# </div>
# </div> </div>
# <div class="clearfix"></div>
# <div class="powered-by twelve-col last-col"><a href="https://portal.ehawaii.gov">Powered by eHawaii.gov</a></div>
# <div class="clearfix"></div>
# <div class="twelve-col last-col" id="copyright_info">
# <span>Copyright © 2020, State of Hawaii. All rights reserved. </span>
# </div>
# <div class="clearfix"></div>
# </div>
# </div>
# <script type="text/javascript">
# var cfflinkhashtags = "true";
# </script>
# <script src="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/simple_announcer/includes/jquery_cookie/jquery.cookie.js?ver=5.4.1" type="text/javascript"></script>
# <script src="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/simple_announcer/includes/js/init.js?ver=5.4.1" type="text/javascript"></script>
# <script src="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/supertables/js/jquery.supertable.min.js?ver=version" type="text/javascript"></script>
# <script src="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/supertables/js/jquery.dataTables.min.js?ver=version" type="text/javascript"></script>
# <script src="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/supertables/js/supertables_init.js?ver=version" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var thickboxL10n = {"next":"Next >","prev":"< Prev","image":"Image","of":"of","close":"Close","noiframes":"This feature requires inline frames. You have iframes disabled or your browser does not support them.","loadingAnimation":"https:\/\/health.hawaii.gov\/coronavirusdisease2019\/wp-includes\/js\/thickbox\/loadingAnimation.gif"};
# /* ]]> */
# </script>
# <script src="https://health.hawaii.gov/coronavirusdisease2019/wp-includes/js/thickbox/thickbox.js?ver=3.1-20121105" type="text/javascript"></script>
# <script src="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/custom-facebook-feed/js/cff-scripts.js?ver=2.14.1" type="text/javascript"></script>
# <script src="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/responsive-lightbox/assets/nivo/nivo-lightbox.min.js?ver=2.2.2" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var rlArgs = {"script":"nivo","selector":"lightbox","customEvents":"","activeGalleries":"1","effect":"fade","clickOverlayToClose":"1","keyboardNav":"1","errorMessage":"The requested content cannot be loaded. Please try again later.","woocommerce_gallery":"0","ajaxurl":"https:\/\/health.hawaii.gov\/coronavirusdisease2019\/wp-admin\/admin-ajax.php","nonce":"b002d50d6e"};
# /* ]]> */
# </script>
# <script src="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/responsive-lightbox/js/front.js?ver=2.2.2" type="text/javascript"></script>
# <script src="https://health.hawaii.gov/coronavirusdisease2019/wp-content/themes/hic_state_template_parent/includes/nivo_slider/jquery.nivo.slider.pack.js?ver=5.4.1" type="text/javascript"></script>
# <script src="https://health.hawaii.gov/coronavirusdisease2019/wp-content/themes/hic_state_template_parent/js/init.js?ver=5.4.1" type="text/javascript"></script>
# <script src="https://health.hawaii.gov/coronavirusdisease2019/wp-content/themes/hic_state_template_parent/js/superclick.js?ver=5.4.1" type="text/javascript"></script>
# <script src="https://health.hawaii.gov/coronavirusdisease2019/wp-content/plugins/page-links-to/dist/new-tab.js?ver=3.3.3" type="text/javascript"></script>
# <script src="https://health.hawaii.gov/coronavirusdisease2019/wp-includes/js/wp-embed.min.js?ver=5.4.1" type="text/javascript"></script>
# <script>
# 		/*<![CDATA[*/
# 		(function() {
# 			var sz = document.createElement('script'); sz.type = 'text/javascript'; sz.async = true;
# 			sz.src = '//siteimproveanalytics.com/js/siteanalyze_6126231.js';
# 			var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(sz, s);
# 		})();
# 		/*]]>*/
# 	</script>
# </div>
# <script>
#         var $buoop = {vs:{i:7,f:3.6,o:10.6,s:4,n:9}}
#         $buoop.ol = window.onload;
#         window.onload=function(){
#         try {if ($buoop.ol) $buoop.ol();}catch (e) {}
#         var e = document.createElement("script");
#         e.setAttribute("type", "text/javascript");
#          e.setAttribute("src", "https://browser-update.org/update.js");
#         document.body.appendChild(e);
#     }
#     </script>
# <script src="//tools.cdc.gov/TemplatePackage/contrib/widgets/tp-widget-external-loader.js"></script>
# <noscript>You need javascript enabled to view this content or go to <a href="//tools.cdc.gov/api/v2/resources/media/403370/noscript">source URL</a>.</noscript>
# </body></html>

# %%
#Total coronavirus (COVID-19) cases in Honolulu County, HI, USA
HI_cases = soup2.find_all('span', attrs={'class': 'label'})[2]
HI_cases_value = soup2.find_all('span', attrs={'class': 'value'})[2]
cases = HI_cases_value.text
pprint(HI_cases.text + HI_cases_value.text)
# Out:
# 'Honolulu County:421'

# %%
#Total coronavirus (COVID-19) cases in Hawaii, USA
HI_deaths = soup2.find_all('span', attrs={'class': 'label'})[8]
HI_deaths_value = soup2.find_all('span', attrs={'class': 'value'})[8]
deaths = HI_deaths_value.text
pprint(HI_deaths.text + HI_deaths_value.text)
# Out:
# 'Hawaii deaths:17'

# %%
Covid_cases['HI'].extend([int(cases),int(deaths)])
Covid_cases
# Out:
# defaultdict(list, {'LA': [55968, 2384], 'HI': [421, 17]})

# %% [markdown]
# **New Delhi, India**

# %%
Covid_df = pd.read_csv("state_wise_daily_India.csv", sep = ",", header = 0, parse_dates = [0])
print(Covid_df.keys())
Covid_df = Covid_df[["Date","Status","DL"]]
Covid_df.head()
# Out:
# Index(['Date', 'Status', 'TT', 'AN', 'AP', 'AR', 'AS', 'BR', 'CH', 'CT', 'DN',
#        'DD', 'DL', 'GA', 'GJ', 'HR', 'HP', 'JK', 'JH', 'KA', 'KL', 'LA', 'LD',
#        'MP', 'MH', 'MN', 'ML', 'MZ', 'NL', 'OR', 'PY', 'PB', 'RJ', 'SK', 'TN',
#        'TG', 'TR', 'UP', 'UT', 'WB', 'UN'],
#       dtype='object')
#         Date     Status  DL
# 0 2020-03-14  Confirmed   7
# 1 2020-03-14  Recovered   1
# 2 2020-03-14   Deceased   1
# 3 2020-03-15  Confirmed   0
# 4 2020-03-15  Recovered   1

# %%
Covid_df_ND = Covid_df.groupby('Status').sum()
cases = Covid_df_ND.loc['Confirmed']['DL']
deaths = Covid_df_ND.loc['Deceased']['DL']

# %%
Covid_cases['ND'].extend([cases,deaths])
Covid_cases
# Out:
# defaultdict(list, {'LA': [55968, 2384], 'HI': [421, 17], 'ND': [11659, 194]})

# %% [markdown]
# **Seoul, South Korea**

# %%
text = urllib.request.urlopen("http://ncov.mohw.go.kr/en/bdBoardList.do?brdId=16&brdGubun=162&dataGubun=&ncvContSeq=&contSeq=&board_id=").read()

# %%
soup = BeautifulSoup(text, 'html.parser')

# %%
table = soup.find('table','num')
table_head = table.find('thead').find_all('tr')
t_header_values = table_head[1].find_all('th')
headers = [t_header.text for t_header in t_header_values]

# %%
tbody = table.find('tbody')
trows = tbody.find_all('tr')
trows[1]
# Out:
# <tr><th scope="row">Seoul</th><td class="number" headers="status_level l_type1">1</td><td class="number" headers="status_level l_type2">1</td><td class="number" headers="status_level l_type3">0</td><td class="number" headers="status_con s_type1">862</td><td class="number" headers="status_con s_type2">231</td><td class="number" headers="status_con s_type3">627</td><td class="number" headers="status_con s_type4">4</td><td class="number" headers="status_con s_type5">8.86</td></tr>

# %%
#as of 26 May
table_dict = {}
tcol_head = trows[1].find('th')
table_dict['City/Province'] = tcol_head.text
tcols = trows[1].find_all('td')
for ix, tcol in enumerate(tcols):
    table_dict[headers[ix]] = tcol.text
pprint(table_dict)
# Out:
# {'City/Province': 'Seoul',
#  'Confirmed Cases': '862',
#  'Daily Change': '1',
#  'Deceased': '4',
#  'Imported cases': '1',
#  'Incidence (*)': '8.86',
#  'Isolated': '231',
#  'Local outbreak': '0',
#  'Released from Quarantine': '627'}

# %%
Covid_cases['SE'].extend([int(table_dict['Confirmed Cases']),int(table_dict['Deceased'])])
Covid_cases
# Out:
# defaultdict(list,
#             {'LA': [55968, 2384],
#              'HI': [421, 17],
#              'ND': [11659, 194],
#              'SE': [862, 4]})

# %% [markdown]
# **Beijing, China**

# %%
text = urllib.request.urlopen("https://voice.baidu.com/act/newpneumonia/newpneumonia/?from=osari_pc_1").read()

# %%
soup_china = BeautifulSoup(text, 'html.parser')
soup_china.find_all('table','VirusTable_1-1-264_38pQEh')
# Out:
# []

# %%
table_dict_Bei = {}
table_dict_Bei['City/Province'] = 'Beijing'
table_dict_Bei['Confirmed'] = 593
table_dict_Bei['Recovered'] = 581
table_dict_Bei['Deceased'] = 9
pprint(table_dict_Bei)
# Out:
# {'City/Province': 'Beijing', 'Confirmed': 593, 'Deceased': 9, 'Recovered': 581}

# %%
Covid_cases['BE'].extend([int(table_dict_Bei['Confirmed']),int(table_dict_Bei['Deceased'])])
Covid_cases
# Out:
# defaultdict(list,
#             {'LA': [55968, 2384],
#              'HI': [421, 17],
#              'ND': [11659, 194],
#              'SE': [862, 4],
#              'BE': [593, 9]})

# %%
Covid_Cases = {'Confirmed': [Covid_cases['LA'][0], Covid_cases['HI'][0], Covid_cases['ND'][0], Covid_cases['SE'][0], Covid_cases['BE'][0]],
        'Deaths': [Covid_cases['LA'][1],Covid_cases['HI'][1], Covid_cases['ND'][1], Covid_cases['SE'][1], Covid_cases['BE'][1]]
        }
df_covid_cases = pd.DataFrame(Covid_Cases, columns = ['Confirmed','Deaths'], index=['Los Angeles, CA, USA','Honolulu, HI, USA','New Delhi, India','Seoul, South Korea','Beijing, China'])
print (df_covid_cases)
# Out:
#                       Confirmed  Deaths
# Los Angeles, CA, USA      55968    2384
# Honolulu, HI, USA           421      17
# New Delhi, India          11659     194
# Seoul, South Korea          862       4
# Beijing, China              593       9

# %% [markdown]
# ### Air Quality Measurements

# %% [markdown]
# **Connecting to the API Endpoints and Data Examples**

# %%
targets = ['Los Angeles, CA, USA', 'Honolulu, HI, USA', 'New Delhi, India', 'Seoul, South Korea', 'Beijing, China']
API_key_breeze = 'de44f9a4e9ed4d35805911e1ac946f73'
#coordinates for testing
la = [34.0522, 118.2437]
honolulu = [39.9526, 75.1652]
delhi = [28.6139, 77.2090]
seoul = [37.5665, 126.9780]
beijing = [39.9042, 116.4074]
coordinates = np.array([la, honolulu, delhi, seoul, beijing], np.float32)

# %%
air_quality = list()
for i in coordinates:
    json_data = requests.get('https://api.breezometer.com/air-quality/v2/current-conditions?lat='+ str(i[0]) +'&lon='+ str(i[1]) + '&key='+ API_key_breeze + '&features=breezometer_aqi,local_aqi,health_recommendations,sources_and_effects,pollutants_concentrations,pollutants_aqi_information')
    air_quality.append(dict(json_data.json()))

# %%
air_quality_range = list()
for i in coordinates:
    json_data = requests.get('https://api.breezometer.com/baqi/?datetime=2020-03-18T15:00:00&lat='+ str(i[0]) +'&lon='+ str(i[1]) + '&key='+ API_key_breeze + '&features=breezometer_aqi,local_aqi,health_recommendations,sources_and_effects,pollutants_concentrations,pollutants_aqi_information')
    air_quality_range.append(dict(json_data.json()))

# %%
air_quality[0]['data']
# Out:
# {'datetime': '2020-06-01T22:00:00Z',
#  'data_available': True,
#  'indexes': {'baqi': {'display_name': 'BreezoMeter AQI',
#    'aqi': 38,
#    'aqi_display': '38',
#    'color': '#FFBA00',
#    'category': 'Low air quality',
#    'dominant_pollutant': 'pm25'},
#   'chn_mep': {'display_name': 'AQI (CN)',
#    'aqi': 73,
#    'aqi_display': '73',
#    'color': '#FFFF00',
#    'category': 'Good air quality',
#    'dominant_pollutant': 'pm10'}},
#  'pollutants': {'co': {'display_name': 'CO',
#    'full_name': 'Carbon monoxide',
#    'aqi_information': {'baqi': {'display_name': 'BreezoMeter AQI',
#      'aqi': 94,
#      'aqi_display': '94',
#      'color': '#009E3A',
#      'category': 'Excellent air quality'}},
#    'concentration': {'value': 737.64, 'units': 'ppb'},
#    'sources_and_effects': {'sources': 'Typically originates from incomplete combustion of carbon fuels, such as that which occurs in car engines and power plants.',
#     'effects': 'When inhaled, carbon monoxide can prevent the blood from carrying oxygen. Exposure may cause dizziness, nausea and headaches. Exposure to extreme concentrations can lead to loss of consciousness.'}},
#   'no2': {'display_name': 'NO2',
#    'full_name': 'Nitrogen dioxide',
#    'aqi_information': {'baqi': {'display_name': 'BreezoMeter AQI',
#      'aqi': 92,
#      'aqi_display': '92',
#      'color': '#009E3A',
#      'category': 'Excellent air quality'}},
#    'concentration': {'value': 10.82, 'units': 'ppb'},
#    'sources_and_effects': {'sources': 'Main sources are fuel burning processes, such as those used in industry and transportation.',
#     'effects': 'Exposure may cause increased bronchial reactivity in patients with asthma, lung function decline in patients with COPD, and increased risk of respiratory infections, especially in young children.'}},
#   'o3': {'display_name': 'O3',
#    'full_name': 'Ozone',
#    'aqi_information': {'baqi': {'display_name': 'BreezoMeter AQI',
#      'aqi': 52,
#      'aqi_display': '52',
#      'color': '#FFFF00',
#      'category': 'Moderate air quality'}},
#    'concentration': {'value': 60.73, 'units': 'ppb'},
#    'sources_and_effects': {'sources': 'Ozone is created in a chemical reaction between atmospheric oxygen, nitrogen oxides, carbon monoxide and organic compounds, in the presence of sunlight.',
#     'effects': 'Ozone can irritate the airways and cause coughing, a burning sensation, wheezing and shortness of breath. Additionally, ozone is one of the major components of photochemical smog.'}},
#   'pm10': {'display_name': 'PM10',
#    'full_name': 'Inhalable particulate matter (<10µm)',
#    'aqi_information': {'baqi': {'display_name': 'BreezoMeter AQI',
#      'aqi': 41,
#      'aqi_display': '41',
#      'color': '#FFFF00',
#      'category': 'Moderate air quality'}},
#    'concentration': {'value': 87.26, 'units': 'ug/m3'},
#    'sources_and_effects': {'sources': 'Main sources are combustion processes (e.g. indoor heating, wildfires), mechanical processes (e.g. construction, mineral dust, agriculture) and biological particles (e.g. pollen, bacteria, mold).',
#     'effects': 'Inhalable particles can penetrate into the lungs. Short term exposure can cause irritation of the airways, coughing, and aggravation of heart and lung diseases, expressed as difficulty breathing, heart attacks and even premature death.'}},
#   'pm25': {'display_name': 'PM2.5',
#    'full_name': 'Fine particulate matter (<2.5µm)',
#    'aqi_information': {'baqi': {'display_name': 'BreezoMeter AQI',
#      'aqi': 38,
#      'aqi_display': '38',
#      'color': '#FF8C00',
#      'category': 'Low air quality'}},
#    'concentration': {'value': 49.83, 'units': 'ug/m3'},
#    'sources_and_effects': {'sources': 'Main sources are combustion processes (e.g. power plants, indoor heating, car exhausts, wildfires), mechanical processes (e.g. construction, mineral dust) and biological particles (e.g. bacteria, viruses).',
#     'effects': 'Fine particles can penetrate into the lungs and bloodstream. Short term exposure can cause irritation of the airways, coughing and aggravation of heart and lung diseases, expressed as difficulty breathing, heart attacks and even premature death.'}},
#   'so2': {'display_name': 'SO2',
#    'full_name': 'Sulfur dioxide',
#    'aqi_information': {'baqi': {'display_name': 'BreezoMeter AQI',
#      'aqi': 99,
#      'aqi_display': '99',
#      'color': '#009E3A',
#      'category': 'Excellent air quality'}},
#    'concentration': {'value': 1.56, 'units': 'ppb'},
#    'sources_and_effects': {'sources': 'Main sources are burning processes of sulfur-containing fuel in industry, transportation and power plants.',
#     'effects': 'Exposure causes irritation of the respiratory tract, coughing and generates local inflammatory reactions. These in turn, may cause aggravation of lung diseases, even with short term exposure.'}}},
#  'health_recommendations': {'general_population': 'Reduce the intensity of your outdoor activities. It is recommended to limit the time you are near busy roads, construction sites, open fires and other sources of smoke. Staying indoors with an activated air filtration system would be best for your long term health.',
#   'elderly': 'Avoid intense activities outdoors or postpone them to the early morning when ozone levels tend to be lower. Stay away from busy roads, construction sites, open fires and other sources of smoke. Staying indoors with an activated air filtration system would be best for your long term health.',
#   'lung_diseases': 'Avoid intense activities outdoors or postpone them to the early morning when ozone levels tend to be lower. Keep relevant medication(s) available and consult a doctor with any questions. Stay away from busy roads, open fires and other sources of smoke. Staying indoors with an activated air filtration system would be best for your long term health.',
#   'heart_diseases': 'Avoid intense activities outdoors. Keep relevant medication(s) available and consult a doctor with any questions. Stay away from busy roads, construction sites, open fires and other sources of smoke. Staying indoors with an activated air filtration system would be best for your long term health.',
#   'active': 'Avoid intense activities outdoors or postpone them to the early morning when ozone levels tend to be lower. Stay away from busy roads, construction sites, open fires and other sources of smoke. Staying indoors with an activated air filtration system would be best for your long term health.',
#   'pregnant_women': 'To keep you and your baby healthy, avoid intense activities outdoors or postpone them to the early morning when ozone levels tend to be lower. Stay away from busy roads, construction sites, open fires and other sources of smoke. Staying indoors with an activated air filtration system would be best for your long term health.',
#   'children': 'Avoid intense activities outdoors or postpone them to the early morning when ozone levels tend to be lower. Stay away from busy roads, construction sites, open fires and other sources of smoke. Staying indoors with an activated air filtration system would be best for your long term health.'}}

# %%
date_time = [x['data']['datetime'] for x in air_quality]
date_time
# Out:
# ['2020-06-01T22:00:00Z',
#  '2020-06-01T22:00:00Z',
#  '2020-06-01T22:00:00Z',
#  '2020-06-01T22:00:00Z',
#  '2020-06-01T22:00:00Z']

# %%
dominant_pollutants = [x['data']['indexes']['baqi']['dominant_pollutant'] for x in air_quality]
dominant_pollutants
# Out:
# ['pm25', 'pm10', 'pm25', 'pm25', 'pm25']

# %%
aqi_value = [x['data']['indexes']['baqi']['aqi'] for x in air_quality]
aqi_value
# Out:
# [38, 34, 34, 68, 70]

# %%
category = [x['data']['indexes']['baqi']['category'] for x in air_quality]
category
# Out:
# ['Low air quality',
#  'Low air quality',
#  'Low air quality',
#  'Good air quality',
#  'Good air quality']

# %%
pollutants = [x['data']['pollutants'] for x in air_quality]
pollutants[2].keys()
# Out:
# dict_keys(['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'])

# %%
def concentration(i):
    pollutant_concentration = defaultdict(dict)
    for data in pollutants[i]:
        pollutant_concentration[i].update({data : str(pollutants[i][data]['concentration']['value'])+' '+pollutants[i][data]['concentration']['units']})
    return pollutant_concentration

# %%
pollutant_conc = []
for i in range(len(air_quality)):
    dict_values = concentration(i).values()
    pollutant_conc.extend(dict_values)
pollutant_conc
# Out:
# [{'co': '737.64 ppb',
#   'no2': '10.82 ppb',
#   'o3': '60.73 ppb',
#   'pm10': '87.26 ug/m3',
#   'pm25': '49.83 ug/m3',
#   'so2': '1.56 ppb'},
#  {'co': '213.12 ppb',
#   'no2': '8.73 ppb',
#   'o3': '26.21 ppb',
#   'pm10': '119.95 ug/m3',
#   'pm25': '39.08 ug/m3',
#   'so2': '0.82 ppb'},
#  {'co': '940.61 ppb',
#   'no2': '14.75 ppb',
#   'o3': '9.78 ppb',
#   'pm10': '117 ug/m3',
#   'pm25': '63.77 ug/m3',
#   'so2': '7.71 ppb'},
#  {'co': '407.53 ppb',
#   'no2': '15.95 ppb',
#   'o3': '25.64 ppb',
#   'pm10': '20.97 ug/m3',
#   'pm25': '19.79 ug/m3',
#   'so2': '2.37 ppb'},
#  {'co': '397.66 ppb',
#   'no2': '14.75 ppb',
#   'o3': '18.57 ppb',
#   'pm10': '21.44 ug/m3',
#   'pm25': '18.71 ug/m3',
#   'so2': '1.02 ppb'}]

# %%
health_recommendations = [x['data']['health_recommendations'] for x in air_quality]
health_recommendations[0]
# Out:
# {'general_population': 'Reduce the intensity of your outdoor activities. It is recommended to limit the time you are near busy roads, construction sites, open fires and other sources of smoke. Staying indoors with an activated air filtration system would be best for your long term health.',
#  'elderly': 'Avoid intense activities outdoors or postpone them to the early morning when ozone levels tend to be lower. Stay away from busy roads, construction sites, open fires and other sources of smoke. Staying indoors with an activated air filtration system would be best for your long term health.',
#  'lung_diseases': 'Avoid intense activities outdoors or postpone them to the early morning when ozone levels tend to be lower. Keep relevant medication(s) available and consult a doctor with any questions. Stay away from busy roads, open fires and other sources of smoke. Staying indoors with an activated air filtration system would be best for your long term health.',
#  'heart_diseases': 'Avoid intense activities outdoors. Keep relevant medication(s) available and consult a doctor with any questions. Stay away from busy roads, construction sites, open fires and other sources of smoke. Staying indoors with an activated air filtration system would be best for your long term health.',
#  'active': 'Avoid intense activities outdoors or postpone them to the early morning when ozone levels tend to be lower. Stay away from busy roads, construction sites, open fires and other sources of smoke. Staying indoors with an activated air filtration system would be best for your long term health.',
#  'pregnant_women': 'To keep you and your baby healthy, avoid intense activities outdoors or postpone them to the early morning when ozone levels tend to be lower. Stay away from busy roads, construction sites, open fires and other sources of smoke. Staying indoors with an activated air filtration system would be best for your long term health.',
#  'children': 'Avoid intense activities outdoors or postpone them to the early morning when ozone levels tend to be lower. Stay away from busy roads, construction sites, open fires and other sources of smoke. Staying indoors with an activated air filtration system would be best for your long term health.'}

# %% [markdown]
# ### Air Quality Image Comparison

# %%
my_folder = "./AirQuality/"
if not os.path.exists(my_folder):
    os.makedirs(my_folder)

# %%
image_before_url = [
    "https://i.insider.com/5afade3b5e48ec42008b4677?width=1300&format=jpeg&auto=webp", #Los Angeles
    "https://dcewboipbvgi2.cloudfront.net/sites/default/files/slideshows/01112012_Job_Cities_Honolulu_slideshow.jpg", # Honolulu
    "https://i.insider.com/5e9f37e90fc6390d3e782de7?width=1300&format=jpeg&auto=webp", #New Delhi
    "https://s3.us-east-2.amazonaws.com/albiladpress/eimages/news/2019/01/thumbnails/main/f28190409591.jpg", # Seoul
    "https://cdn1.i-scmp.com/sites/default/files/styles/1200x800/public/images/methode/2017/09/15/8ef7089e-99d2-11e7-a089-5a7a21c623ca_1280x720_221218.jpg?itok=WwFhsEc1" #Beijing
                   ]
image_after_url = [
    "https://i.insider.com/5e9f40c069852511e12b58ce?width=1300&format=jpeg&auto=webp", #Los Angeles, California
    "https://media.tacdn.com/media/attractions-splice-spp-674x446/06/70/65/6e.jpg", #Honolulu, USA
    "https://i.insider.com/5e9f380c6985250dd77a48d6?width=1300&format=jpeg&auto=webp", #New Delhi, India
    "https://api.time.com/wp-content/uploads/2020/04/south-korea-daily-coronavirus-cases.jpg", #Seoul, South Korea
    "https://checkinprice.com/wp-content/uploads/2018/02/average-minimum-salary-beijing-china.jpg", #Beijing China 
                   ]
count = 0
for i in image_before_url:
    image = requests.get(i)
    with open( "AirQuality/image_before_"+ str(count)+".png", "wb")as fh:
        fh.write(image.content)
    count += 1
    
count = 0
for i in image_after_url:
    image = requests.get(i)
    with open( "AirQuality/image_after_"+ str(count)+".png", "wb")as fh:
        fh.write(image.content)
    count += 1

# %%
from PIL import Image  
for i in range(5):
    im = Image.open(r"AirQuality/image_before_" + str(i) +".png")
for i in range(5):
    im = Image.open(r"AirQuality/image_after_" + str(i) +".png")

# %%
dataframe = pd.DataFrame({'Confirmed': df_covid_cases['Confirmed'], 'Deceased': df_covid_cases['Deaths'], 'Date and Time': date_time,
                         'Dominant Pollutants': dominant_pollutants, 'AQI': aqi_value, 'Category': category, 'Pollutants': pollutant_conc,
                         'Health Recommendations': health_recommendations, 'Images before Covid Pandemic': image_before_url,
                         'Images After Covid Pandemic': image_after_url})

# %%
dataframe.head()
# Out:
#                       Confirmed  Deceased         Date and Time  \
# Los Angeles, CA, USA      55968      2384  2020-06-01T22:00:00Z
# Honolulu, HI, USA           421        17  2020-06-01T22:00:00Z
# New Delhi, India          11659       194  2020-06-01T22:00:00Z
# Seoul, South Korea          862         4  2020-06-01T22:00:00Z
# Beijing, China              593         9  2020-06-01T22:00:00Z
#
#                      Dominant Pollutants  AQI          Category  \
# Los Angeles, CA, USA                pm25   38   Low air quality
# Honolulu, HI, USA                   pm10   34   Low air quality
# New Delhi, India                    pm25   34   Low air quality
# Seoul, South Korea                  pm25   68  Good air quality
# Beijing, China                      pm25   70  Good air quality
#
#                                                              Pollutants  \
# Los Angeles, CA, USA  {'co': '737.64 ppb', 'no2': '10.82 ppb', 'o3':...
# Honolulu, HI, USA     {'co': '213.12 ppb', 'no2': '8.73 ppb', 'o3': ...
# New Delhi, India      {'co': '940.61 ppb', 'no2': '14.75 ppb', 'o3':...
# Seoul, South Korea    {'co': '407.53 ppb', 'no2': '15.95 ppb', 'o3':...
# Beijing, China        {'co': '397.66 ppb', 'no2': '14.75 ppb', 'o3':...
#
#                                                  Health Recommendations  \
# Los Angeles, CA, USA  {'general_population': 'Reduce the intensity o...
# Honolulu, HI, USA     {'general_population': 'Reduce the intensity o...
# New Delhi, India      {'general_population': 'Reduce the intensity o...
# Seoul, South Korea    {'general_population': 'With this level of air...
# Beijing, China        {'general_population': 'With this level of air...
#
#                                            Images before Covid Pandemic  \
# Los Angeles, CA, USA  https://i.insider.com/5afade3b5e48ec42008b4677...
# Honolulu, HI, USA     https://dcewboipbvgi2.cloudfront.net/sites/def...
# New Delhi, India      https://i.insider.com/5e9f37e90fc6390d3e782de7...
# Seoul, South Korea    https://s3.us-east-2.amazonaws.com/albiladpres...
# Beijing, China        https://cdn1.i-scmp.com/sites/default/files/st...
#
#                                             Images After Covid Pandemic
# Los Angeles, CA, USA  https://i.insider.com/5e9f40c069852511e12b58ce...
# Honolulu, HI, USA     https://media.tacdn.com/media/attractions-spli...
# New Delhi, India      https://i.insider.com/5e9f380c6985250dd77a48d6...
# Seoul, South Korea    https://api.time.com/wp-content/uploads/2020/0...
# Beijing, China        https://checkinprice.com/wp-content/uploads/20...

# %% [markdown]
# **Future Consideration**
#
# By using this data we hope to be able to map the air quality over time as these locations relax social distancing rules and stay at home orders.
#
# We can compare the before and after images by making use of the Mean Squared Error (MSE) and the Structural Similarity Index (SSIM) functions

# %% [markdown]
# ### TEAM MEMBERS
#
# **Madhumitha Santhana Krishnan**
#
# Madhu is working as a Data Specialist at a healthcare company and pursuing MS in Data Science at Drexel. She has experience in python programming and SQL and expects to apply this experience towards cleansing and pre-processing the data in this project.
#
# **Aviad Reuvenny**
#
# Aviad is pursuing a graduate degree in Project Management at Drexel University. He works full time for Comcast on the Business Process Management team within the commercial side of the business where my role is most analogous to a project manager. His day to day involves collaborating and communicating ﻿﻿﻿﻿across engineering, operations, legal and finance teams to ensure alignment across projects. Most of his previous work experience focused on mining, gathering and analyzing data and he has an interest in machine learning and artificial intelligence, one of the reasons I enrolled in this course. Aviad has worked in various industries from healthcare to e-commerce and have spent time at both small start-ups and large Fortune 500 companies and started my career in government.
#
#
# **Kunal Sharma**
#
# Kunal is pursuing a graduate degree in Data Science at Drexel University. He has project experience from his previous courses in Python and Java. He is interested in Computer Vision and Software development. He is currently a full time student and looking for a co-op or internship opportunity during the summer 2020.
#
# **Shannon Zapotocky**
#
# Shannon earned her BBA degree in Accounting and is a CPA. She is currently pursuing a graduate certificate in Applied Data Science.  Shannon will aid in the extraction of data, assist in providing logic to our objective and data visualization.

# %% [markdown]
# ### References
#
# - [Pennsylvania Department of Environmental Protection](https://www.dep.pa.gov/Business/Air/BAQ/MonitoringTopics/AirQualityIndex/Pages/default.aspx)
# - [United State Environmental Protection Agency](https://aqs.epa.gov/aqsweb/documents/data_api.html)
# - https://towardsdatascience.com/google-trends-api-for-python-a84bc25db88f
# - https://towardsdatascience.com/image-pre-processing-c1aec0be3edf
# - https://api.covid19india.org/csv/
# - https://www.pyimagesearch.com/2014/09/15/python-compare-two-images/
